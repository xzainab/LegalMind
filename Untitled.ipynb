# %%
import hashlib
from pathlib import Path
import sentence_transformers
import torch
from langchain_chroma import Chroma
from langchain_core.embeddings import Embeddings
from tqdm.notebook import tqdm

# %%
class LangChainE5Embeddings(Embeddings):

  def __init__(self, model_name: str = "intfloat/multilingual-e5-base"):
    # Detects NVIDIA GPU (cuda), Apple Silicon (mps), or CPU
    if torch.cuda.is_available():
      self.device = "cuda"
    elif torch.backends.mps.is_available():
      self.device = "mps"
    else:
      self.device = "cpu"

    print(f"Loading embedding model [{model_name}] on device: {self.device}")
    self.model = sentence_transformers.SentenceTransformer(
        model_name, device=self.device
    )

  def embed_documents(self, texts: list[str]) -> list[list[float]]:
    prefixed = [f"passage: {doc}" for doc in texts]
    # batch_size=128 is smooth & fast on 16GB RAM hardware
    return self.model.encode(
        prefixed,
        batch_size=128,
        normalize_embeddings=True,
        convert_to_numpy=True,
    ).tolist()

  def embed_query(self, text: str) -> list[float]:
    return self.model.encode(
        f"query: {text}", normalize_embeddings=True, convert_to_numpy=True
    ).tolist()

# %%
def chunk_text_file(
    text: str, chunk_size_words: int = 200, overlap_words: int = 30
) -> list[str]:
  words = text.split()
  if not words:
    return []
  chunks = []
  for i in range(0, len(words), chunk_size_words - overlap_words):
    chunk_words = words[i : i + chunk_size_words]
    chunks.append(" ".join(chunk_words))
    if i + chunk_size_words >= len(words):
      break
  return chunks

# %%
BASE_DIR = Path.cwd()
MAIN_CATEGORIES = [
    "أحكام التمييز",
    "المحكمة الدستورية",
    "هيئة التشريع و الرأي القانوني",
]

embeddings = LangChainE5Embeddings()
# Out:
# Loading embedding model [intfloat/multilingual-e5-base] on device: cpu
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
vector_db = Chroma(
    collection_name="legal_documents",
    embedding_function=embeddings,
    persist_directory="./legal_chroma_db",
    collection_metadata={"hnsw:space": "cosine"},
)

# %%
BUFFER_SIZE = 4000
docs_buffer, meta_buffer, ids_buffer = [], [], []
total_indexed = 0

# %%
for category in MAIN_CATEGORIES:
  cat_path = BASE_DIR / category
  if not cat_path.exists():
    print(f"Warning: Directory {cat_path} not found.")
    continue

  file_list = list(cat_path.rglob("*.txt"))
  print(f"\nProcessing {len(file_list)} files in [{category}]...")

  for file_path in tqdm(file_list, desc=category):
    try:
      with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()

      chunks = chunk_text_file(content)
      rel_path = str(file_path.relative_to(cat_path))

      for idx, chunk in enumerate(chunks):
        # Unique Hash ID calculation prevents duplicate ID errors
        unique_seed = f"{category}_{rel_path}_{idx}"
        chunk_id = hashlib.md5(unique_seed.encode("utf-8")).hexdigest()

        docs_buffer.append(chunk)
        meta_buffer.append({
            "source_file": file_path.name,
            "main_category": category,
            "sub_path": rel_path,
            "chunk_index": idx,
        })
        ids_buffer.append(chunk_id)

        # Flush buffer to Chroma DB when full
        if len(docs_buffer) >= BUFFER_SIZE:
          vector_db.add_texts(
              texts=docs_buffer, metadatas=meta_buffer, ids=ids_buffer
          )
          total_indexed += len(docs_buffer)
          docs_buffer.clear()
          meta_buffer.clear()
          ids_buffer.clear()

    except Exception as e:
      print(f"Error reading file {file_path}: {e}")
# Out:
# Processing 6357 files in [أحكام التمييز]...
# أحكام التمييز:   0%|          | 0/6357 [00:00<?, ?it/s]
# Error reading file C:\Users\Fatima Khalifa\GA_DSB\LegalMind\أحكام التمييز\قاعدة_الخانة_1000_طعن_239.txt: Expected IDs to be unique, found duplicates of: 78b9217399b9766944fd296b68dcd418 in upsert.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 42
#      38           docs_buffer.clear()
#      39           meta_buffer.clear()
#      40           ids_buffer.clear()
#      41
# ---> 42     except Exception as e:
#      43       print(f"Error reading file {file_path}: {e}")
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\langchain_chroma\vectorstores.py:627, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     625 texts = list(texts)
#     626 if self._embedding_function is not None:
# --> 627     embeddings = self._embedding_function.embed_documents(texts)
#     628 if metadatas:
#     629     # fill metadatas with empty dicts if somebody
#     630     # did not specify metadata for all texts
#     631     length_diff = len(texts) - len(metadatas)
#
# Cell In[2], line 20, in LangChainE5Embeddings.embed_documents(self, texts)
#      17   def embed_documents(self, texts: list[str]) -> list[list[float]]:
#      18     prefixed = [f"passage: {doc}" for doc in texts]
#      19     # batch_size=128 is smooth & fast on 16GB RAM hardware
# ---> 20     return self.model.encode(
#      21         prefixed,
#      22         batch_size=128,
#      23         normalize_embeddings=True,
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sentence_transformers\util\decorators.py:46, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44         else:
#      45             kwargs.pop(old_name)
# ---> 46 return func(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sentence_transformers\sentence_transformer\model.py:941, in SentenceTransformer.encode(self, inputs, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#     938 features = batch_to_device(features, device)
#     940 # Route through __call__ so that model.compile() applies to the forward pass.
# --> 941 out_features = self(features, **kwargs)
#     942 if is_hpu:
#     943     out_features = copy.deepcopy(out_features)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sentence_transformers\base\model.py:569, in BaseModel.forward(self, input, **kwargs)
#     563             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     564         module_kwargs = {
#     565             key: value
#     566             for key, value in kwargs.items()
#     567             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#     568         }
# --> 569     input = module(input, **module_kwargs)
#     570 return input
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\sentence_transformers\base\modules\transformer.py:1650, in Transformer.forward(self, features, **kwargs)
#    1647 if method_output_name is not None and "hidden_states" in method_output_name:
#    1648     filtered_kwargs["output_hidden_states"] = True
# -> 1650 model_output = model_method(**filtered_kwargs)
#    1652 embedding = model_output
#    1653 if method_output_name is not None:
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\utils\generic.py:1068, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#    1066             output = func(self, *args, **kwargs)
#    1067     else:
# -> 1068         output = func(self, *args, **kwargs)
#    1069 # Restore original config value
#    1070 finally:
#    1071     if is_causal is not None:
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\utils\output_capturing.py:262, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     260 # Run the forward
#     261 try:
# --> 262     outputs = func(self, *args, **kwargs)
#     263 # Reset the states
#     264 finally:
#     265     _active_collector.reset(output_token)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:637, in XLMRobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, **kwargs)
#     621 embedding_output = self.embeddings(
#     622     input_ids=input_ids,
#     623     position_ids=position_ids,
#    (...)    626     past_key_values_length=past_key_values_length,
#     627 )
#     629 attention_mask, encoder_attention_mask = self._create_attention_masks(
#     630     attention_mask=attention_mask,
#     631     encoder_attention_mask=encoder_attention_mask,
#    (...)    634     past_key_values=past_key_values,
#     635 )
# --> 637 encoder_outputs = self.encoder(
#     638     embedding_output,
#     639     attention_mask=attention_mask,
#     640     encoder_hidden_states=encoder_hidden_states,
#     641     encoder_attention_mask=encoder_attention_mask,
#     642     past_key_values=past_key_values,
#     643     use_cache=use_cache,
#     644     position_ids=position_ids,
#     645     **kwargs,
#     646 )
#     647 sequence_output = encoder_outputs.last_hidden_state
#     648 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:531, in XLMRobertaEncoder.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, **kwargs)
#     520 def forward(
#     521     self,
#     522     hidden_states: torch.Tensor,
#    (...)    528     **kwargs: Unpack[TransformersKwargs],
#     529 ) -> tuple[torch.Tensor] | BaseModelOutputWithPastAndCrossAttentions:
#     530     for i, layer_module in enumerate(self.layer):
# --> 531         hidden_states = layer_module(
#     532             hidden_states,
#     533             attention_mask,
#     534             encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     535             encoder_attention_mask=encoder_attention_mask,
#     536             past_key_values=past_key_values,
#     537             **kwargs,
#     538         )
#     540     return BaseModelOutputWithPastAndCrossAttentions(
#     541         last_hidden_state=hidden_states,
#     542         past_key_values=past_key_values if use_cache else None,
#     543     )
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\modeling_layers.py:114, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#     111         logger.warning_once(message)
#     113     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# --> 114 return super().__call__(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:430, in XLMRobertaLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, **kwargs)
#     421 def forward(
#     422     self,
#     423     hidden_states: torch.Tensor,
#    (...)    428     **kwargs: Unpack[TransformersKwargs],
#     429 ) -> torch.Tensor:
# --> 430     self_attention_output, _ = self.attention(
#     431         hidden_states,
#     432         attention_mask,
#     433         past_key_values=past_key_values,
#     434         **kwargs,
#     435     )
#     436     attention_output = self_attention_output
#     438     if self.is_decoder and encoder_hidden_states is not None:
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:361, in XLMRobertaAttention.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, **kwargs)
#     351 def forward(
#     352     self,
#     353     hidden_states: torch.Tensor,
#    (...)    358     **kwargs: Unpack[TransformersKwargs],
#     359 ) -> tuple[torch.Tensor]:
#     360     attention_mask = attention_mask if not self.is_cross_attention else encoder_attention_mask
# --> 361     attention_output, attn_weights = self.self(
#     362         hidden_states,
#     363         encoder_hidden_states=encoder_hidden_states,
#     364         attention_mask=attention_mask,
#     365         past_key_values=past_key_values,
#     366         **kwargs,
#     367     )
#     368     attention_output = self.output(attention_output, hidden_states)
#     369     return attention_output, attn_weights
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\transformers\models\xlm_roberta\modeling_xlm_roberta.py:222, in XLMRobertaSelfAttention.forward(self, hidden_states, attention_mask, past_key_values, **kwargs)
#     219 hidden_shape = (*input_shape, -1, self.attention_head_size)
#     221 # get all proj
# --> 222 query_layer = self.query(hidden_states).view(*hidden_shape).transpose(1, 2)
#     223 key_layer = self.key(hidden_states).view(*hidden_shape).transpose(1, 2)
#     224 value_layer = self.value(hidden_states).view(*hidden_shape).transpose(1, 2)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\GA_DSB\ga_dsb_env\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
if docs_buffer:
  vector_db.add_texts(texts=docs_buffer, metadatas=meta_buffer, ids=ids_buffer)
  total_indexed += len(docs_buffer)

print(
    f"\nDone! Successfully embedded and indexed {total_indexed} total chunks."
)
print(f"Total Database Count: {vector_db._collection.count()} chunks.")a
