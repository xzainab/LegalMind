# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma    # new version
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_ollama import ChatOllama, OllamaEmbeddings
import os 
from langchain_community.document_loaders import TextLoader
# Out:
# /var/folders/9t/2fbrff9979b0mg7vphsy68900000gn/T/ipykernel_23783/3925217984.py:8: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
# LOCAL EMBEDDINGS using Ollama (No API key needed)
embeddings = OllamaEmbeddings(model="bge-m3")

# %%
# 1. Load the text files from your folder
folder_path = "my_txt_files" 
documents = []

for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(folder_path, filename)
        # Using utf-8 encoding is crucial for reading Arabic characters properly
        loader = TextLoader(file_path, encoding="utf-8")
        documents.extend(loader.load())

# 2. Split documents into manageable chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=50)
chunks = text_splitter.split_documents(documents)

# %%
# Initialize an empty Chroma database with your model settings
# (Using a clean name to completely avoid dimension conflicts)
db = Chroma(
    embedding_function=embeddings,
    collection_name="my_rag_project", #collection of all the documents for the same project. This name is saved inside the database 
    persist_directory="./my_vector_db",
    collection_metadata={"hnsw:space": "cosine"}  # <-- CRUCIAL FOR ARABIC SEMANTICS

)

# %%
# Add documents in small, bite-sized batches of 10 chunks
batch_size = 10
for i in range(0, len(chunks), batch_size):
    batch = chunks[i : i + batch_size]
    db.add_documents(batch)
    print(f"Successfully processed chunks {i} to {i + len(batch)}")

print("==== Ingestion Complete! Data saved permanently to disk ====")
# Out:
# Successfully processed chunks 0 to 10
# Successfully processed chunks 10 to 20
# Successfully processed chunks 20 to 30
# Successfully processed chunks 30 to 40
# Successfully processed chunks 40 to 50
# Successfully processed chunks 50 to 60
# Successfully processed chunks 60 to 70
# Successfully processed chunks 70 to 80
# Successfully processed chunks 80 to 90
# Successfully processed chunks 90 to 100
# Successfully processed chunks 100 to 110
# Successfully processed chunks 110 to 120
# Successfully processed chunks 120 to 130
# Successfully processed chunks 130 to 140
# Successfully processed chunks 140 to 150
# Successfully processed chunks 150 to 160
# Successfully processed chunks 160 to 170
# Successfully processed chunks 170 to 180
# Successfully processed chunks 180 to 190
# Successfully processed chunks 190 to 200
# Successfully processed chunks 200 to 210
# Successfully processed chunks 210 to 220
# Successfully processed chunks 220 to 230
# Successfully processed chunks 230 to 240
# Successfully processed chunks 240 to 250
# Successfully processed chunks 250 to 260
# Successfully processed chunks 260 to 270
# Successfully processed chunks 270 to 280
# Successfully processed chunks 280 to 290
# Successfully processed chunks 290 to 300
# Successfully processed chunks 300 to 310
# Successfully processed chunks 310 to 320
# Successfully processed chunks 320 to 330
# Successfully processed chunks 330 to 340
# Successfully processed chunks 340 to 350
# Successfully processed chunks 350 to 360
# Successfully processed chunks 360 to 370
# Successfully processed chunks 370 to 380
# Successfully processed chunks 380 to 390
# Successfully processed chunks 390 to 400
# Successfully processed chunks 400 to 410
# Successfully processed chunks 410 to 420
# Successfully processed chunks 420 to 430
# Successfully processed chunks 430 to 440
# Successfully processed chunks 440 to 450
# Successfully processed chunks 450 to 460
# Successfully processed chunks 460 to 470
# Successfully processed chunks 470 to 480
# Successfully processed chunks 480 to 490
# Successfully processed chunks 490 to 500
# Successfully processed chunks 500 to 510
# Successfully processed chunks 510 to 520
# Successfully processed chunks 520 to 530
# Successfully processed chunks 530 to 540
# Successfully processed chunks 540 to 550
# Successfully processed chunks 550 to 560
# Successfully processed chunks 560 to 570
# Successfully processed chunks 570 to 580
# Successfully processed chunks 580 to 590
# Successfully processed chunks 590 to 600
# Successfully processed chunks 600 to 610
# Successfully processed chunks 610 to 620
# Successfully processed chunks 620 to 630
# Successfully processed chunks 630 to 640
# Successfully processed chunks 640 to 650
# Successfully processed chunks 650 to 660
# Successfully processed chunks 660 to 670
# Successfully processed chunks 670 to 680
# Successfully processed chunks 680 to 690
# Successfully processed chunks 690 to 700
# Successfully processed chunks 700 to 710
# Successfully processed chunks 710 to 720
# Successfully processed chunks 720 to 730
# Successfully processed chunks 730 to 740
# Successfully processed chunks 740 to 750
# Successfully processed chunks 750 to 760
# Successfully processed chunks 760 to 770
# Successfully processed chunks 770 to 780
# Successfully processed chunks 780 to 790
# Successfully processed chunks 790 to 800
# Successfully processed chunks 800 to 810
# Successfully processed chunks 810 to 820
# Successfully processed chunks 820 to 830
# Successfully processed chunks 830 to 840
# Successfully processed chunks 840 to 850
# Successfully processed chunks 850 to 860
# Successfully processed chunks 860 to 870
# Successfully processed chunks 870 to 880
# Successfully processed chunks 880 to 890
# Successfully processed chunks 890 to 900
# Successfully processed chunks 900 to 910
# Successfully processed chunks 910 to 920
# Successfully processed chunks 920 to 930
# Successfully processed chunks 930 to 940
# Successfully processed chunks 940 to 950
# Successfully processed chunks 950 to 960
# Successfully processed chunks 960 to 970
# Successfully processed chunks 970 to 980
# Successfully processed chunks 980 to 990
# Successfully processed chunks 990 to 1000
# Successfully processed chunks 1000 to 1010
# Successfully processed chunks 1010 to 1020
# Successfully processed chunks 1020 to 1030
# Successfully processed chunks 1030 to 1040
# Successfully processed chunks 1040 to 1050
# Successfully processed chunks 1050 to 1060
# Successfully processed chunks 1060 to 1070
# Successfully processed chunks 1070 to 1080
# Successfully processed chunks 1080 to 1090
# Successfully processed chunks 1090 to 1100
# Successfully processed chunks 1100 to 1110
# Successfully processed chunks 1110 to 1120
# Successfully processed chunks 1120 to 1130
# Successfully processed chunks 1130 to 1140
# Successfully processed chunks 1140 to 1150
# Successfully processed chunks 1150 to 1160
# Successfully processed chunks 1160 to 1170
# Successfully processed chunks 1170 to 1180
# Successfully processed chunks 1180 to 1190
# Successfully processed chunks 1190 to 1200
# Successfully processed chunks 1200 to 1210
# Successfully processed chunks 1210 to 1220
# Successfully processed chunks 1220 to 1230
# Successfully processed chunks 1230 to 1240
# Successfully processed chunks 1240 to 1250
# Successfully processed chunks 1250 to 1260
# Successfully processed chunks 1260 to 1270
# Successfully processed chunks 1270 to 1280
# Successfully processed chunks 1280 to 1290
# Successfully processed chunks 1290 to 1300
# Successfully processed chunks 1300 to 1310
# Successfully processed chunks 1310 to 1320
# Successfully processed chunks 1320 to 1330
# Successfully processed chunks 1330 to 1340
# Successfully processed chunks 1340 to 1350
# Successfully processed chunks 1350 to 1360
# Successfully processed chunks 1360 to 1370
# Successfully processed chunks 1370 to 1380
# Successfully processed chunks 1380 to 1390
# Successfully processed chunks 1390 to 1400
# Successfully processed chunks 1400 to 1410
# Successfully processed chunks 1410 to 1420
# Successfully processed chunks 1420 to 1430
# Successfully processed chunks 1430 to 1440
# Successfully processed chunks 1440 to 1450
# Successfully processed chunks 1450 to 1460
# Successfully processed chunks 1460 to 1470
# Successfully processed chunks 1470 to 1480
# Successfully processed chunks 1480 to 1490
# Successfully processed chunks 1490 to 1500
# Successfully processed chunks 1500 to 1510
# Successfully processed chunks 1510 to 1520
# Successfully processed chunks 1520 to 1530
# Successfully processed chunks 1530 to 1540
# Successfully processed chunks 1540 to 1550
# Successfully processed chunks 1550 to 1560
# Successfully processed chunks 1560 to 1570
# Successfully processed chunks 1570 to 1580
# Successfully processed chunks 1580 to 1590
# Successfully processed chunks 1590 to 1600
# Successfully processed chunks 1600 to 1610
# Successfully processed chunks 1610 to 1620
# Successfully processed chunks 1620 to 1630
# Successfully processed chunks 1630 to 1640
# Successfully processed chunks 1640 to 1650
# Successfully processed chunks 1650 to 1660
# Successfully processed chunks 1660 to 1670
# Successfully processed chunks 1670 to 1680
# Successfully processed chunks 1680 to 1690
# Successfully processed chunks 1690 to 1700
# Successfully processed chunks 1700 to 1710
# Successfully processed chunks 1710 to 1720
# Successfully processed chunks 1720 to 1730
# Successfully processed chunks 1730 to 1740
# Successfully processed chunks 1740 to 1750
# Successfully processed chunks 1750 to 1760
# Successfully processed chunks 1760 to 1770
# Successfully processed chunks 1770 to 1780
# Successfully processed chunks 1780 to 1790
# Successfully processed chunks 1790 to 1800
# Successfully processed chunks 1800 to 1810
# Successfully processed chunks 1810 to 1820
# Successfully processed chunks 1820 to 1830
# Successfully processed chunks 1830 to 1840
# Successfully processed chunks 1840 to 1850
# Successfully processed chunks 1850 to 1860
# Successfully processed chunks 1860 to 1870
# Successfully processed chunks 1870 to 1880
# Successfully processed chunks 1880 to 1890
# Successfully processed chunks 1890 to 1900
# Successfully processed chunks 1900 to 1910
# Successfully processed chunks 1910 to 1920
# Successfully processed chunks 1920 to 1930
# Successfully processed chunks 1930 to 1940
# Successfully processed chunks 1940 to 1950
# Successfully processed chunks 1950 to 1960
# Successfully processed chunks 1960 to 1970
# Successfully processed chunks 1970 to 1980
# Successfully processed chunks 1980 to 1990
# Successfully processed chunks 1990 to 2000
# Successfully processed chunks 2000 to 2010
# Successfully processed chunks 2010 to 2020
# Successfully processed chunks 2020 to 2030
# Successfully processed chunks 2030 to 2040
# Successfully processed chunks 2040 to 2050
# Successfully processed chunks 2050 to 2060
# Successfully processed chunks 2060 to 2070
# Successfully processed chunks 2070 to 2080
# Successfully processed chunks 2080 to 2090
# Successfully processed chunks 2090 to 2100
# Successfully processed chunks 2100 to 2110
# Successfully processed chunks 2110 to 2120
# Successfully processed chunks 2120 to 2130
# Successfully processed chunks 2130 to 2140
# Successfully processed chunks 2140 to 2150
# Successfully processed chunks 2150 to 2160
# Successfully processed chunks 2160 to 2170
# Successfully processed chunks 2170 to 2180
# Successfully processed chunks 2180 to 2190
# Successfully processed chunks 2190 to 2200
# Successfully processed chunks 2200 to 2210
# Successfully processed chunks 2210 to 2220
# Successfully processed chunks 2220 to 2230
# Successfully processed chunks 2230 to 2240
# Successfully processed chunks 2240 to 2250
# Successfully processed chunks 2250 to 2260
# Successfully processed chunks 2260 to 2270
# Successfully processed chunks 2270 to 2280
# Successfully processed chunks 2280 to 2290
# Successfully processed chunks 2290 to 2300
# Successfully processed chunks 2300 to 2310
# Successfully processed chunks 2310 to 2320
# Successfully processed chunks 2320 to 2330
# Successfully processed chunks 2330 to 2340
# Successfully processed chunks 2340 to 2350
# Successfully processed chunks 2350 to 2360
# Successfully processed chunks 2360 to 2370
# Successfully processed chunks 2370 to 2380
# Successfully processed chunks 2380 to 2390
# Successfully processed chunks 2390 to 2400
# Successfully processed chunks 2400 to 2410
# Successfully processed chunks 2410 to 2420
# Successfully processed chunks 2420 to 2430
# Successfully processed chunks 2430 to 2440
# Successfully processed chunks 2440 to 2450
# Successfully processed chunks 2450 to 2460
# Successfully processed chunks 2460 to 2470
# Successfully processed chunks 2470 to 2480
# Successfully processed chunks 2480 to 2490
# Successfully processed chunks 2490 to 2500
# Successfully processed chunks 2500 to 2510
# Successfully processed chunks 2510 to 2520
# Successfully processed chunks 2520 to 2530
# Successfully processed chunks 2530 to 2540
# Successfully processed chunks 2540 to 2550
# Successfully processed chunks 2550 to 2560
# Successfully processed chunks 2560 to 2570
# Successfully processed chunks 2570 to 2580
# Successfully processed chunks 2580 to 2590
# Successfully processed chunks 2590 to 2600
# Successfully processed chunks 2600 to 2610
# Successfully processed chunks 2610 to 2620
# Successfully processed chunks 2620 to 2630
# Successfully processed chunks 2630 to 2640
# Successfully processed chunks 2640 to 2650
# Successfully processed chunks 2650 to 2660
# Successfully processed chunks 2660 to 2670
# Successfully processed chunks 2670 to 2680
# Successfully processed chunks 2680 to 2690
# Successfully processed chunks 2690 to 2700
# Successfully processed chunks 2700 to 2710
# Successfully processed chunks 2710 to 2720
# Successfully processed chunks 2720 to 2730
# Successfully processed chunks 2730 to 2740
# Successfully processed chunks 2740 to 2750
# Successfully processed chunks 2750 to 2760
# Successfully processed chunks 2760 to 2770
# Successfully processed chunks 2770 to 2780
# Successfully processed chunks 2780 to 2790
# Successfully processed chunks 2790 to 2800
# Successfully processed chunks 2800 to 2810
# Successfully processed chunks 2810 to 2820
# Successfully processed chunks 2820 to 2830
# Successfully processed chunks 2830 to 2840
# Successfully processed chunks 2840 to 2850
# Successfully processed chunks 2850 to 2860
# Successfully processed chunks 2860 to 2870
# Successfully processed chunks 2870 to 2880
# Successfully processed chunks 2880 to 2890
# Successfully processed chunks 2890 to 2900
# Successfully processed chunks 2900 to 2910
# Successfully processed chunks 2910 to 2920
# Successfully processed chunks 2920 to 2930
# Successfully processed chunks 2930 to 2940
# Successfully processed chunks 2940 to 2950
# Successfully processed chunks 2950 to 2960
# Successfully processed chunks 2960 to 2970
# Successfully processed chunks 2970 to 2980
# Successfully processed chunks 2980 to 2990
# Successfully processed chunks 2990 to 3000
# Successfully processed chunks 3000 to 3010
# Successfully processed chunks 3010 to 3020
# Successfully processed chunks 3020 to 3030
# Successfully processed chunks 3030 to 3040
# Successfully processed chunks 3040 to 3050
# Successfully processed chunks 3050 to 3060
# Successfully processed chunks 3060 to 3070
# Successfully processed chunks 3070 to 3080
# Successfully processed chunks 3080 to 3090
# Successfully processed chunks 3090 to 3100
# Successfully processed chunks 3100 to 3110
# Successfully processed chunks 3110 to 3120
# Successfully processed chunks 3120 to 3130
# Successfully processed chunks 3130 to 3140
# Successfully processed chunks 3140 to 3150
# Successfully processed chunks 3150 to 3160
# Successfully processed chunks 3160 to 3170
# Successfully processed chunks 3170 to 3180
# Successfully processed chunks 3180 to 3190
# Successfully processed chunks 3190 to 3200
# Successfully processed chunks 3200 to 3210
# Successfully processed chunks 3210 to 3220
# Successfully processed chunks 3220 to 3230
# Successfully processed chunks 3230 to 3240
# Successfully processed chunks 3240 to 3250
# Successfully processed chunks 3250 to 3260
# Successfully processed chunks 3260 to 3270
# Successfully processed chunks 3270 to 3280
# Successfully processed chunks 3280 to 3290
# Successfully processed chunks 3290 to 3300
# Successfully processed chunks 3300 to 3310
# Successfully processed chunks 3310 to 3320
# Successfully processed chunks 3320 to 3330
# Successfully processed chunks 3330 to 3340
# Successfully processed chunks 3340 to 3350
# Successfully processed chunks 3350 to 3360
# Successfully processed chunks 3360 to 3370
# Successfully processed chunks 3370 to 3380
# Successfully processed chunks 3380 to 3390
# Successfully processed chunks 3390 to 3400
# Successfully processed chunks 3400 to 3410
# Successfully processed chunks 3410 to 3420
# Successfully processed chunks 3420 to 3430
# Successfully processed chunks 3430 to 3440
# Successfully processed chunks 3440 to 3450
# Successfully processed chunks 3450 to 3460
# Successfully processed chunks 3460 to 3470
# Successfully processed chunks 3470 to 3480
# Successfully processed chunks 3480 to 3490
# Successfully processed chunks 3490 to 3500
# Successfully processed chunks 3500 to 3510
# Successfully processed chunks 3510 to 3520
# Successfully processed chunks 3520 to 3530
# Successfully processed chunks 3530 to 3540
# Successfully processed chunks 3540 to 3550
# Successfully processed chunks 3550 to 3560
# Successfully processed chunks 3560 to 3570
# Successfully processed chunks 3570 to 3580
# Successfully processed chunks 3580 to 3590
# Successfully processed chunks 3590 to 3600
# Successfully processed chunks 3600 to 3610
# Successfully processed chunks 3610 to 3620
# Successfully processed chunks 3620 to 3630
# Successfully processed chunks 3630 to 3640
# Successfully processed chunks 3640 to 3650
# Successfully processed chunks 3650 to 3660
# Successfully processed chunks 3660 to 3670
# Successfully processed chunks 3670 to 3680
# Successfully processed chunks 3680 to 3690
# Successfully processed chunks 3690 to 3700
# Successfully processed chunks 3700 to 3710
# Successfully processed chunks 3710 to 3720
# Successfully processed chunks 3720 to 3730
# Successfully processed chunks 3730 to 3740
# Successfully processed chunks 3740 to 3750
# Successfully processed chunks 3750 to 3760
# Successfully processed chunks 3760 to 3770
# Successfully processed chunks 3770 to 3780
# Successfully processed chunks 3780 to 3790
# Successfully processed chunks 3790 to 3800
# Successfully processed chunks 3800 to 3810
# Successfully processed chunks 3810 to 3820
# Successfully processed chunks 3820 to 3830
# Successfully processed chunks 3830 to 3840
# Successfully processed chunks 3840 to 3850
# Successfully processed chunks 3850 to 3860
# Successfully processed chunks 3860 to 3870
# Successfully processed chunks 3870 to 3880
# Successfully processed chunks 3880 to 3890
# Successfully processed chunks 3890 to 3900
# Successfully processed chunks 3900 to 3910
# Successfully processed chunks 3910 to 3920
# Successfully processed chunks 3920 to 3930
# Successfully processed chunks 3930 to 3940
# Successfully processed chunks 3940 to 3950
# Successfully processed chunks 3950 to 3960
# Successfully processed chunks 3960 to 3970
# Successfully processed chunks 3970 to 3980
# Successfully processed chunks 3980 to 3990
# Successfully processed chunks 3990 to 4000
# Successfully processed chunks 4000 to 4010
# Successfully processed chunks 4010 to 4020
# Successfully processed chunks 4020 to 4030
# Successfully processed chunks 4030 to 4040
# Successfully processed chunks 4040 to 4050
# Successfully processed chunks 4050 to 4060
# Successfully processed chunks 4060 to 4070
# Successfully processed chunks 4070 to 4080
# Successfully processed chunks 4080 to 4090
# Successfully processed chunks 4090 to 4100
# Successfully processed chunks 4100 to 4110
# Successfully processed chunks 4110 to 4120
# Successfully processed chunks 4120 to 4130
# Successfully processed chunks 4130 to 4140
# Successfully processed chunks 4140 to 4150
# Successfully processed chunks 4150 to 4160
# Successfully processed chunks 4160 to 4170
# Successfully processed chunks 4170 to 4180
# Successfully processed chunks 4180 to 4190
# Successfully processed chunks 4190 to 4200
# Successfully processed chunks 4200 to 4210
# Successfully processed chunks 4210 to 4220
# Successfully processed chunks 4220 to 4230
# Successfully processed chunks 4230 to 4240
# Successfully processed chunks 4240 to 4250
# Successfully processed chunks 4250 to 4260
# Successfully processed chunks 4260 to 4270
# Successfully processed chunks 4270 to 4280
# Successfully processed chunks 4280 to 4290
# Successfully processed chunks 4290 to 4300
# Successfully processed chunks 4300 to 4310
# Successfully processed chunks 4310 to 4320
# Successfully processed chunks 4320 to 4330
# Successfully processed chunks 4330 to 4340
# Successfully processed chunks 4340 to 4350
# Successfully processed chunks 4350 to 4360
# Successfully processed chunks 4360 to 4370
# Successfully processed chunks 4370 to 4380
# Successfully processed chunks 4380 to 4390
# Successfully processed chunks 4390 to 4400
# Successfully processed chunks 4400 to 4410
# Successfully processed chunks 4410 to 4420
# Successfully processed chunks 4420 to 4430
# Successfully processed chunks 4430 to 4440
# Successfully processed chunks 4440 to 4450
# Successfully processed chunks 4450 to 4460
# Successfully processed chunks 4460 to 4470
# Successfully processed chunks 4470 to 4480
# Successfully processed chunks 4480 to 4490
# Successfully processed chunks 4490 to 4500
# Successfully processed chunks 4500 to 4510
# Successfully processed chunks 4510 to 4520
# Successfully processed chunks 4520 to 4530
# Successfully processed chunks 4530 to 4540
# Successfully processed chunks 4540 to 4550
# Successfully processed chunks 4550 to 4560
# Successfully processed chunks 4560 to 4570
# Successfully processed chunks 4570 to 4580
# Successfully processed chunks 4580 to 4590
# Successfully processed chunks 4590 to 4600
# Successfully processed chunks 4600 to 4610
# Successfully processed chunks 4610 to 4620
# Successfully processed chunks 4620 to 4630
# Successfully processed chunks 4630 to 4640
# Successfully processed chunks 4640 to 4650
# Successfully processed chunks 4650 to 4660
# Successfully processed chunks 4660 to 4670
# Successfully processed chunks 4670 to 4680
# Successfully processed chunks 4680 to 4690
# Successfully processed chunks 4690 to 4700
# Successfully processed chunks 4700 to 4710
# Successfully processed chunks 4710 to 4720
# Successfully processed chunks 4720 to 4730
# Successfully processed chunks 4730 to 4740
# Successfully processed chunks 4740 to 4750
# Successfully processed chunks 4750 to 4760
# Successfully processed chunks 4760 to 4770
# Successfully processed chunks 4770 to 4780
# Successfully processed chunks 4780 to 4790
# Successfully processed chunks 4790 to 4800
# Successfully processed chunks 4800 to 4810
# Successfully processed chunks 4810 to 4820
# Successfully processed chunks 4820 to 4830
# Successfully processed chunks 4830 to 4840
# Successfully processed chunks 4840 to 4850
# Successfully processed chunks 4850 to 4860
# Successfully processed chunks 4860 to 4870
# Successfully processed chunks 4870 to 4880
# Successfully processed chunks 4880 to 4890
# Successfully processed chunks 4890 to 4900
# Successfully processed chunks 4900 to 4910
# Successfully processed chunks 4910 to 4920
# Successfully processed chunks 4920 to 4930
# Successfully processed chunks 4930 to 4940
# Successfully processed chunks 4940 to 4950
# Successfully processed chunks 4950 to 4960
# Successfully processed chunks 4960 to 4970
# Successfully processed chunks 4970 to 4980
# Successfully processed chunks 4980 to 4990
# Successfully processed chunks 4990 to 5000
# Successfully processed chunks 5000 to 5010
# Successfully processed chunks 5010 to 5020
# Successfully processed chunks 5020 to 5030
# Successfully processed chunks 5030 to 5040
# Successfully processed chunks 5040 to 5050
# Successfully processed chunks 5050 to 5060
# Successfully processed chunks 5060 to 5070
# Successfully processed chunks 5070 to 5080
# Successfully processed chunks 5080 to 5090
# Successfully processed chunks 5090 to 5100
# Successfully processed chunks 5100 to 5110
# Successfully processed chunks 5110 to 5120
# Successfully processed chunks 5120 to 5130
# Successfully processed chunks 5130 to 5140
# Successfully processed chunks 5140 to 5150
# Successfully processed chunks 5150 to 5160
# Successfully processed chunks 5160 to 5170
# Successfully processed chunks 5170 to 5180
# Successfully processed chunks 5180 to 5190
# Successfully processed chunks 5190 to 5200
# Successfully processed chunks 5200 to 5210
# Successfully processed chunks 5210 to 5220
# Successfully processed chunks 5220 to 5230
# Successfully processed chunks 5230 to 5240
# Successfully processed chunks 5240 to 5250
# Successfully processed chunks 5250 to 5260
# Successfully processed chunks 5260 to 5270
# Successfully processed chunks 5270 to 5280
# Successfully processed chunks 5280 to 5290
# Successfully processed chunks 5290 to 5300
# Successfully processed chunks 5300 to 5310
# Successfully processed chunks 5310 to 5320
# Successfully processed chunks 5320 to 5330
# Successfully processed chunks 5330 to 5340
# Successfully processed chunks 5340 to 5350
# Successfully processed chunks 5350 to 5360
# Successfully processed chunks 5360 to 5370
# Successfully processed chunks 5370 to 5380
# Successfully processed chunks 5380 to 5390
# Successfully processed chunks 5390 to 5400
# Successfully processed chunks 5400 to 5410
# Successfully processed chunks 5410 to 5420
# Successfully processed chunks 5420 to 5430
# Successfully processed chunks 5430 to 5440
# Successfully processed chunks 5440 to 5450
# Successfully processed chunks 5450 to 5460
# Successfully processed chunks 5460 to 5470
# Successfully processed chunks 5470 to 5480
# Successfully processed chunks 5480 to 5490
# Successfully processed chunks 5490 to 5500
# Successfully processed chunks 5500 to 5510
# Successfully processed chunks 5510 to 5520
# Successfully processed chunks 5520 to 5530
# Successfully processed chunks 5530 to 5540
# Successfully processed chunks 5540 to 5550
# Successfully processed chunks 5550 to 5560
# Successfully processed chunks 5560 to 5570
# Successfully processed chunks 5570 to 5580
# Successfully processed chunks 5580 to 5590
# Successfully processed chunks 5590 to 5600
# Successfully processed chunks 5600 to 5610
# Successfully processed chunks 5610 to 5620
# Successfully processed chunks 5620 to 5630
# Successfully processed chunks 5630 to 5640
# Successfully processed chunks 5640 to 5650
# Successfully processed chunks 5650 to 5660
# Successfully processed chunks 5660 to 5670
# Successfully processed chunks 5670 to 5680
# Successfully processed chunks 5680 to 5690
# Successfully processed chunks 5690 to 5700
# Successfully processed chunks 5700 to 5710
# Successfully processed chunks 5710 to 5720
# Successfully processed chunks 5720 to 5730
# Successfully processed chunks 5730 to 5740
# Successfully processed chunks 5740 to 5750
# Successfully processed chunks 5750 to 5760
# Successfully processed chunks 5760 to 5770
# Successfully processed chunks 5770 to 5780
# Successfully processed chunks 5780 to 5790
# Successfully processed chunks 5790 to 5800
# Successfully processed chunks 5800 to 5810
# Successfully processed chunks 5810 to 5820
# Successfully processed chunks 5820 to 5830
# Successfully processed chunks 5830 to 5840
# Successfully processed chunks 5840 to 5850
# Successfully processed chunks 5850 to 5860
# Successfully processed chunks 5860 to 5870
# Successfully processed chunks 5870 to 5880
# Successfully processed chunks 5880 to 5890
# Successfully processed chunks 5890 to 5900
# Successfully processed chunks 5900 to 5910
# Successfully processed chunks 5910 to 5920
# Successfully processed chunks 5920 to 5930
# Successfully processed chunks 5930 to 5940
# Successfully processed chunks 5940 to 5950
# Successfully processed chunks 5950 to 5960
# Successfully processed chunks 5960 to 5970
# Successfully processed chunks 5970 to 5980
# Successfully processed chunks 5980 to 5990
# Successfully processed chunks 5990 to 6000
# Successfully processed chunks 6000 to 6010
# Successfully processed chunks 6010 to 6020
# Successfully processed chunks 6020 to 6030
# Successfully processed chunks 6030 to 6040
# Successfully processed chunks 6040 to 6050
# Successfully processed chunks 6050 to 6060
# Successfully processed chunks 6060 to 6070
# Successfully processed chunks 6070 to 6080
# Successfully processed chunks 6080 to 6090
# Successfully processed chunks 6090 to 6100
# Successfully processed chunks 6100 to 6110
# Successfully processed chunks 6110 to 6120
# Successfully processed chunks 6120 to 6130
# Successfully processed chunks 6130 to 6140
# Successfully processed chunks 6140 to 6150
# Successfully processed chunks 6150 to 6160
# Successfully processed chunks 6160 to 6170
# Successfully processed chunks 6170 to 6180
# Successfully processed chunks 6180 to 6190
# Successfully processed chunks 6190 to 6200
# Successfully processed chunks 6200 to 6210
# Successfully processed chunks 6210 to 6220
# Successfully processed chunks 6220 to 6230
# Successfully processed chunks 6230 to 6240
# Successfully processed chunks 6240 to 6250
# Successfully processed chunks 6250 to 6260
# Successfully processed chunks 6260 to 6270
# Successfully processed chunks 6270 to 6280
# Successfully processed chunks 6280 to 6290
# Successfully processed chunks 6290 to 6300
# Successfully processed chunks 6300 to 6310
# Successfully processed chunks 6310 to 6320
# Successfully processed chunks 6320 to 6330
# Successfully processed chunks 6330 to 6340
# Successfully processed chunks 6340 to 6350
# Successfully processed chunks 6350 to 6360
# Successfully processed chunks 6360 to 6370
# Successfully processed chunks 6370 to 6380
# Successfully processed chunks 6380 to 6390
# Successfully processed chunks 6390 to 6400
# Successfully processed chunks 6400 to 6410
# Successfully processed chunks 6410 to 6420
# Successfully processed chunks 6420 to 6430
# Successfully processed chunks 6430 to 6440
# Successfully processed chunks 6440 to 6450
# Successfully processed chunks 6450 to 6460
# Successfully processed chunks 6460 to 6470
# Successfully processed chunks 6470 to 6480
# Successfully processed chunks 6480 to 6490
# Successfully processed chunks 6490 to 6500
# Successfully processed chunks 6500 to 6510
# Successfully processed chunks 6510 to 6520
# Successfully processed chunks 6520 to 6530
# Successfully processed chunks 6530 to 6540
# Successfully processed chunks 6540 to 6550
# Successfully processed chunks 6550 to 6560
# Successfully processed chunks 6560 to 6570
# Successfully processed chunks 6570 to 6580
# Successfully processed chunks 6580 to 6590
# Successfully processed chunks 6590 to 6600
# Successfully processed chunks 6600 to 6610
# Successfully processed chunks 6610 to 6620
# Successfully processed chunks 6620 to 6630
# Successfully processed chunks 6630 to 6640
# Successfully processed chunks 6640 to 6650
# Successfully processed chunks 6650 to 6660
# Successfully processed chunks 6660 to 6670
# Successfully processed chunks 6670 to 6680
# Successfully processed chunks 6680 to 6690
# Successfully processed chunks 6690 to 6700
# Successfully processed chunks 6700 to 6710
# Successfully processed chunks 6710 to 6720
# Successfully processed chunks 6720 to 6730
# Successfully processed chunks 6730 to 6740
# Successfully processed chunks 6740 to 6750
# Successfully processed chunks 6750 to 6760
# Successfully processed chunks 6760 to 6770
# Successfully processed chunks 6770 to 6780
# Successfully processed chunks 6780 to 6790
# Successfully processed chunks 6790 to 6800
# Successfully processed chunks 6800 to 6810
# Successfully processed chunks 6810 to 6820
# Successfully processed chunks 6820 to 6830
# Successfully processed chunks 6830 to 6840
# Successfully processed chunks 6840 to 6850
# Successfully processed chunks 6850 to 6860
# Successfully processed chunks 6860 to 6870
# Successfully processed chunks 6870 to 6880
# Successfully processed chunks 6880 to 6890
# Successfully processed chunks 6890 to 6900
# Successfully processed chunks 6900 to 6910
# Successfully processed chunks 6910 to 6920
# Successfully processed chunks 6920 to 6930
# Successfully processed chunks 6930 to 6940
# Successfully processed chunks 6940 to 6950
# Successfully processed chunks 6950 to 6960
# Successfully processed chunks 6960 to 6970
# Successfully processed chunks 6970 to 6980
# Successfully processed chunks 6980 to 6990
# Successfully processed chunks 6990 to 7000
# Successfully processed chunks 7000 to 7010
# Successfully processed chunks 7010 to 7020
# Successfully processed chunks 7020 to 7030
# Successfully processed chunks 7030 to 7040
# Successfully processed chunks 7040 to 7050
# Successfully processed chunks 7050 to 7060
# Successfully processed chunks 7060 to 7070
# Successfully processed chunks 7070 to 7080
# Successfully processed chunks 7080 to 7090
# Successfully processed chunks 7090 to 7100
# Successfully processed chunks 7100 to 7110
# Successfully processed chunks 7110 to 7120
# Successfully processed chunks 7120 to 7130
# Successfully processed chunks 7130 to 7140
# Successfully processed chunks 7140 to 7150
# Successfully processed chunks 7150 to 7160
# Successfully processed chunks 7160 to 7170
# Successfully processed chunks 7170 to 7180
# Successfully processed chunks 7180 to 7190
# Successfully processed chunks 7190 to 7200
# Successfully processed chunks 7200 to 7210
# Successfully processed chunks 7210 to 7220
# Successfully processed chunks 7220 to 7230
# Successfully processed chunks 7230 to 7240
# Successfully processed chunks 7240 to 7250
# Successfully processed chunks 7250 to 7260
# Successfully processed chunks 7260 to 7270
# Successfully processed chunks 7270 to 7280
# Successfully processed chunks 7280 to 7290
# Successfully processed chunks 7290 to 7300
# Successfully processed chunks 7300 to 7310
# Successfully processed chunks 7310 to 7320
# Successfully processed chunks 7320 to 7330
# Successfully processed chunks 7330 to 7340
# Successfully processed chunks 7340 to 7350
# Successfully processed chunks 7350 to 7360
# Successfully processed chunks 7360 to 7370
# Successfully processed chunks 7370 to 7380
# Successfully processed chunks 7380 to 7390
# Successfully processed chunks 7390 to 7400
# Successfully processed chunks 7400 to 7410
# Successfully processed chunks 7410 to 7420
# Successfully processed chunks 7420 to 7430
# Successfully processed chunks 7430 to 7440
# Successfully processed chunks 7440 to 7450
# Successfully processed chunks 7450 to 7460
# Successfully processed chunks 7460 to 7470
# Successfully processed chunks 7470 to 7480
# Successfully processed chunks 7480 to 7490
# Successfully processed chunks 7490 to 7500
# Successfully processed chunks 7500 to 7510
# Successfully processed chunks 7510 to 7520
# Successfully processed chunks 7520 to 7530
# Successfully processed chunks 7530 to 7540
# Successfully processed chunks 7540 to 7550
# Successfully processed chunks 7550 to 7560
# Successfully processed chunks 7560 to 7570
# Successfully processed chunks 7570 to 7580
# Successfully processed chunks 7580 to 7590
# Successfully processed chunks 7590 to 7600
# Successfully processed chunks 7600 to 7610
# Successfully processed chunks 7610 to 7620
# Successfully processed chunks 7620 to 7630
# Successfully processed chunks 7630 to 7640
# Successfully processed chunks 7640 to 7650
# Successfully processed chunks 7650 to 7660
# Successfully processed chunks 7660 to 7670
# Successfully processed chunks 7670 to 7680
# Successfully processed chunks 7680 to 7690
# Successfully processed chunks 7690 to 7700
# Successfully processed chunks 7700 to 7710
# Successfully processed chunks 7710 to 7720
# Successfully processed chunks 7720 to 7730
# Successfully processed chunks 7730 to 7740
# Successfully processed chunks 7740 to 7750
# Successfully processed chunks 7750 to 7760
# Successfully processed chunks 7760 to 7770
# Successfully processed chunks 7770 to 7780
# Successfully processed chunks 7780 to 7790
# Successfully processed chunks 7790 to 7800
# Successfully processed chunks 7800 to 7810
# Successfully processed chunks 7810 to 7820
# Successfully processed chunks 7820 to 7830
# Successfully processed chunks 7830 to 7840
# Successfully processed chunks 7840 to 7850
# Successfully processed chunks 7850 to 7860
# Successfully processed chunks 7860 to 7870
# Successfully processed chunks 7870 to 7880
# Successfully processed chunks 7880 to 7890
# Successfully processed chunks 7890 to 7900
# Successfully processed chunks 7900 to 7910
# Successfully processed chunks 7910 to 7920
# Successfully processed chunks 7920 to 7930
# Successfully processed chunks 7930 to 7940
# Successfully processed chunks 7940 to 7950
# Successfully processed chunks 7950 to 7960
# Successfully processed chunks 7960 to 7970
# Successfully processed chunks 7970 to 7980
# Successfully processed chunks 7980 to 7990
# Successfully processed chunks 7990 to 8000
# Successfully processed chunks 8000 to 8010
# Successfully processed chunks 8010 to 8020
# Successfully processed chunks 8020 to 8030
# Successfully processed chunks 8030 to 8040
# Successfully processed chunks 8040 to 8050
# Successfully processed chunks 8050 to 8060
# Successfully processed chunks 8060 to 8070
# Successfully processed chunks 8070 to 8080
# Successfully processed chunks 8080 to 8090
# Successfully processed chunks 8090 to 8100
# Successfully processed chunks 8100 to 8110
# Successfully processed chunks 8110 to 8120
# Successfully processed chunks 8120 to 8130
# Successfully processed chunks 8130 to 8140
# Successfully processed chunks 8140 to 8150
# Successfully processed chunks 8150 to 8160
# Successfully processed chunks 8160 to 8170
# Successfully processed chunks 8170 to 8180
# Successfully processed chunks 8180 to 8190
# Successfully processed chunks 8190 to 8200
# Successfully processed chunks 8200 to 8210
# Successfully processed chunks 8210 to 8220
# Successfully processed chunks 8220 to 8230
# Successfully processed chunks 8230 to 8240
# Successfully processed chunks 8240 to 8250
# Successfully processed chunks 8250 to 8260
# Successfully processed chunks 8260 to 8270
# Successfully processed chunks 8270 to 8280
# Successfully processed chunks 8280 to 8290
# Successfully processed chunks 8290 to 8300
# Successfully processed chunks 8300 to 8310
# Successfully processed chunks 8310 to 8320
# Successfully processed chunks 8320 to 8330
# Successfully processed chunks 8330 to 8340
# Successfully processed chunks 8340 to 8350
# Successfully processed chunks 8350 to 8360
# Successfully processed chunks 8360 to 8370
# Successfully processed chunks 8370 to 8380
# Successfully processed chunks 8380 to 8390
# Successfully processed chunks 8390 to 8400
# Successfully processed chunks 8400 to 8410
# Successfully processed chunks 8410 to 8420
# Successfully processed chunks 8420 to 8430
# Successfully processed chunks 8430 to 8440
# Successfully processed chunks 8440 to 8450
# Successfully processed chunks 8450 to 8460
# Successfully processed chunks 8460 to 8470
# Successfully processed chunks 8470 to 8480
# Successfully processed chunks 8480 to 8490
# Successfully processed chunks 8490 to 8500
# Successfully processed chunks 8500 to 8510
# Successfully processed chunks 8510 to 8520
# Successfully processed chunks 8520 to 8530
# Successfully processed chunks 8530 to 8540
# Successfully processed chunks 8540 to 8550
# Successfully processed chunks 8550 to 8560
# Successfully processed chunks 8560 to 8570
# Successfully processed chunks 8570 to 8580
# Successfully processed chunks 8580 to 8590
# Successfully processed chunks 8590 to 8600
# Successfully processed chunks 8600 to 8610
# Successfully processed chunks 8610 to 8620
# Successfully processed chunks 8620 to 8630
# Successfully processed chunks 8630 to 8640
# Successfully processed chunks 8640 to 8650
# Successfully processed chunks 8650 to 8660
# Successfully processed chunks 8660 to 8670
# Successfully processed chunks 8670 to 8680
# Successfully processed chunks 8680 to 8690
# Successfully processed chunks 8690 to 8700
# Successfully processed chunks 8700 to 8710
# Successfully processed chunks 8710 to 8720
# Successfully processed chunks 8720 to 8730
# Successfully processed chunks 8730 to 8740
# Successfully processed chunks 8740 to 8750
# Successfully processed chunks 8750 to 8760
# Successfully processed chunks 8760 to 8770
# Successfully processed chunks 8770 to 8780
# Successfully processed chunks 8780 to 8790
# Successfully processed chunks 8790 to 8800
# Successfully processed chunks 8800 to 8810
# Successfully processed chunks 8810 to 8820
# Successfully processed chunks 8820 to 8830
# Successfully processed chunks 8830 to 8840
# Successfully processed chunks 8840 to 8850
# Successfully processed chunks 8850 to 8860
# Successfully processed chunks 8860 to 8870
# Successfully processed chunks 8870 to 8880
# Successfully processed chunks 8880 to 8890
# Successfully processed chunks 8890 to 8900
# Successfully processed chunks 8900 to 8910
# Successfully processed chunks 8910 to 8920
# Successfully processed chunks 8920 to 8930
# Successfully processed chunks 8930 to 8940
# Successfully processed chunks 8940 to 8950
# Successfully processed chunks 8950 to 8960
# Successfully processed chunks 8960 to 8970
# Successfully processed chunks 8970 to 8980
# Successfully processed chunks 8980 to 8990
# Successfully processed chunks 8990 to 9000
# Successfully processed chunks 9000 to 9010
# Successfully processed chunks 9010 to 9020
# Successfully processed chunks 9020 to 9030
# Successfully processed chunks 9030 to 9040
# Successfully processed chunks 9040 to 9050
# Successfully processed chunks 9050 to 9060
# Successfully processed chunks 9060 to 9070
# Successfully processed chunks 9070 to 9080
# Successfully processed chunks 9080 to 9090
# Successfully processed chunks 9090 to 9100
# Successfully processed chunks 9100 to 9110
# Successfully processed chunks 9110 to 9120
# Successfully processed chunks 9120 to 9130
# Successfully processed chunks 9130 to 9140
# Successfully processed chunks 9140 to 9150
# Successfully processed chunks 9150 to 9160
# Successfully processed chunks 9160 to 9170
# Successfully processed chunks 9170 to 9180
# Successfully processed chunks 9180 to 9190
# Successfully processed chunks 9190 to 9200
# Successfully processed chunks 9200 to 9210
# Successfully processed chunks 9210 to 9220
# Successfully processed chunks 9220 to 9230
# Successfully processed chunks 9230 to 9240
# Successfully processed chunks 9240 to 9250
# Successfully processed chunks 9250 to 9260
# Successfully processed chunks 9260 to 9270
# Successfully processed chunks 9270 to 9280
# Successfully processed chunks 9280 to 9290
# Successfully processed chunks 9290 to 9300
# Successfully processed chunks 9300 to 9310
# Successfully processed chunks 9310 to 9320
# Successfully processed chunks 9320 to 9330
# Successfully processed chunks 9330 to 9340
# Successfully processed chunks 9340 to 9350
# Successfully processed chunks 9350 to 9360
# Successfully processed chunks 9360 to 9370
# Successfully processed chunks 9370 to 9380
# Successfully processed chunks 9380 to 9390
# Successfully processed chunks 9390 to 9400
# Successfully processed chunks 9400 to 9410
# Successfully processed chunks 9410 to 9420
# Successfully processed chunks 9420 to 9430
# Successfully processed chunks 9430 to 9440
# Successfully processed chunks 9440 to 9450
# Successfully processed chunks 9450 to 9460
# Successfully processed chunks 9460 to 9470
# Successfully processed chunks 9470 to 9480
# Successfully processed chunks 9480 to 9490
# Successfully processed chunks 9490 to 9500
# Successfully processed chunks 9500 to 9510
# Successfully processed chunks 9510 to 9520
# Successfully processed chunks 9520 to 9530
# Successfully processed chunks 9530 to 9540
# Successfully processed chunks 9540 to 9550
# Successfully processed chunks 9550 to 9560
# Successfully processed chunks 9560 to 9570
# Successfully processed chunks 9570 to 9580
# Successfully processed chunks 9580 to 9590
# Successfully processed chunks 9590 to 9600
# Successfully processed chunks 9600 to 9610
# Successfully processed chunks 9610 to 9620
# Successfully processed chunks 9620 to 9630
# Successfully processed chunks 9630 to 9640
# Successfully processed chunks 9640 to 9650
# Successfully processed chunks 9650 to 9660
# Successfully processed chunks 9660 to 9670
# Successfully processed chunks 9670 to 9680
# Successfully processed chunks 9680 to 9690
# Successfully processed chunks 9690 to 9700
# Successfully processed chunks 9700 to 9710
# Successfully processed chunks 9710 to 9720
# Successfully processed chunks 9720 to 9730
# Successfully processed chunks 9730 to 9740
# Successfully processed chunks 9740 to 9750
# Successfully processed chunks 9750 to 9760
# Successfully processed chunks 9760 to 9770
# Successfully processed chunks 9770 to 9780
# Successfully processed chunks 9780 to 9790
# Successfully processed chunks 9790 to 9800
# Successfully processed chunks 9800 to 9810
# Successfully processed chunks 9810 to 9820
# Successfully processed chunks 9820 to 9830
# Successfully processed chunks 9830 to 9840
# Successfully processed chunks 9840 to 9850
# Successfully processed chunks 9850 to 9860
# Successfully processed chunks 9860 to 9870
# Successfully processed chunks 9870 to 9880
# Successfully processed chunks 9880 to 9890
# Successfully processed chunks 9890 to 9900
# Successfully processed chunks 9900 to 9910
# Successfully processed chunks 9910 to 9920
# Successfully processed chunks 9920 to 9930
# Successfully processed chunks 9930 to 9940
# Successfully processed chunks 9940 to 9950
# Successfully processed chunks 9950 to 9960
# Successfully processed chunks 9960 to 9970
# Successfully processed chunks 9970 to 9980
# Successfully processed chunks 9980 to 9990
# Successfully processed chunks 9990 to 10000
# Successfully processed chunks 10000 to 10010
# Successfully processed chunks 10010 to 10020
# Successfully processed chunks 10020 to 10030
# Successfully processed chunks 10030 to 10040
# Successfully processed chunks 10040 to 10050
# Successfully processed chunks 10050 to 10060
# Successfully processed chunks 10060 to 10070
# Successfully processed chunks 10070 to 10080
# Successfully processed chunks 10080 to 10090
# Successfully processed chunks 10090 to 10100
# Successfully processed chunks 10100 to 10110
# Successfully processed chunks 10110 to 10120
# Successfully processed chunks 10120 to 10130
# Successfully processed chunks 10130 to 10140
# Successfully processed chunks 10140 to 10150
# Successfully processed chunks 10150 to 10160
# Successfully processed chunks 10160 to 10170
# Successfully processed chunks 10170 to 10180
# Successfully processed chunks 10180 to 10190
# Successfully processed chunks 10190 to 10200
# Successfully processed chunks 10200 to 10210
# Successfully processed chunks 10210 to 10220
# Successfully processed chunks 10220 to 10230
# Successfully processed chunks 10230 to 10240
# Successfully processed chunks 10240 to 10250
# Successfully processed chunks 10250 to 10260
# Successfully processed chunks 10260 to 10270
# Successfully processed chunks 10270 to 10280
# Successfully processed chunks 10280 to 10290
# Successfully processed chunks 10290 to 10300
# Successfully processed chunks 10300 to 10310
# Successfully processed chunks 10310 to 10320
# Successfully processed chunks 10320 to 10330
# Successfully processed chunks 10330 to 10340
# Successfully processed chunks 10340 to 10350
# Successfully processed chunks 10350 to 10360
# Successfully processed chunks 10360 to 10370
# Successfully processed chunks 10370 to 10380
# Successfully processed chunks 10380 to 10390
# Successfully processed chunks 10390 to 10400
# Successfully processed chunks 10400 to 10410
# Successfully processed chunks 10410 to 10420
# Successfully processed chunks 10420 to 10430
# Successfully processed chunks 10430 to 10440
# Successfully processed chunks 10440 to 10450
# Successfully processed chunks 10450 to 10460
# Successfully processed chunks 10460 to 10470
# Successfully processed chunks 10470 to 10480
# Successfully processed chunks 10480 to 10490
# Successfully processed chunks 10490 to 10500
# Successfully processed chunks 10500 to 10510
# Successfully processed chunks 10510 to 10520
# Successfully processed chunks 10520 to 10530
# Successfully processed chunks 10530 to 10540
# Successfully processed chunks 10540 to 10550
# Successfully processed chunks 10550 to 10560
# Successfully processed chunks 10560 to 10570
# Successfully processed chunks 10570 to 10580
# Successfully processed chunks 10580 to 10590
# Successfully processed chunks 10590 to 10600
# Successfully processed chunks 10600 to 10610
# Successfully processed chunks 10610 to 10620
# Successfully processed chunks 10620 to 10630
# Successfully processed chunks 10630 to 10640
# Successfully processed chunks 10640 to 10650
# Successfully processed chunks 10650 to 10660
# Successfully processed chunks 10660 to 10670
# Successfully processed chunks 10670 to 10680
# Successfully processed chunks 10680 to 10690
# Successfully processed chunks 10690 to 10700
# Successfully processed chunks 10700 to 10710
# Successfully processed chunks 10710 to 10720
# Successfully processed chunks 10720 to 10730
# Successfully processed chunks 10730 to 10740
# Successfully processed chunks 10740 to 10750
# Successfully processed chunks 10750 to 10760
# Successfully processed chunks 10760 to 10770
# Successfully processed chunks 10770 to 10780
# Successfully processed chunks 10780 to 10790
# Successfully processed chunks 10790 to 10800
# Successfully processed chunks 10800 to 10810
# Successfully processed chunks 10810 to 10820
# Successfully processed chunks 10820 to 10830
# Successfully processed chunks 10830 to 10840
# Successfully processed chunks 10840 to 10850
# Successfully processed chunks 10850 to 10860
# Successfully processed chunks 10860 to 10870
# Successfully processed chunks 10870 to 10880
# Successfully processed chunks 10880 to 10890
# Successfully processed chunks 10890 to 10900
# Successfully processed chunks 10900 to 10910
# Successfully processed chunks 10910 to 10920
# Successfully processed chunks 10920 to 10930
# Successfully processed chunks 10930 to 10940
# Successfully processed chunks 10940 to 10950
# Successfully processed chunks 10950 to 10960
# Successfully processed chunks 10960 to 10970
# Successfully processed chunks 10970 to 10980
# Successfully processed chunks 10980 to 10990
# Successfully processed chunks 10990 to 11000
# Successfully processed chunks 11000 to 11010
# Successfully processed chunks 11010 to 11020
# Successfully processed chunks 11020 to 11030
# Successfully processed chunks 11030 to 11040
# Successfully processed chunks 11040 to 11050
# Successfully processed chunks 11050 to 11060
# Successfully processed chunks 11060 to 11070
# Successfully processed chunks 11070 to 11080
# Successfully processed chunks 11080 to 11090
# Successfully processed chunks 11090 to 11100
# Successfully processed chunks 11100 to 11110
# Successfully processed chunks 11110 to 11120
# Successfully processed chunks 11120 to 11130
# Successfully processed chunks 11130 to 11140
# Successfully processed chunks 11140 to 11150
# ...
# Successfully processed chunks 201650 to 201660
# Successfully processed chunks 201660 to 201670
# Successfully processed chunks 201670 to 201680
# Successfully processed chunks 201680 to 201690
# Successfully processed chunks 201690 to 201700
# Successfully processed chunks 201700 to 201710
# Successfully processed chunks 201710 to 201720
# Successfully processed chunks 201720 to 201730
# Successfully processed chunks 201730 to 201740
# Successfully processed chunks 201740 to 201750
# Successfully processed chunks 201750 to 201760
# Successfully processed chunks 201760 to 201770
# Successfully processed chunks 201770 to 201780
# Successfully processed chunks 201780 to 201790
# Successfully processed chunks 201790 to 201800
# Successfully processed chunks 201800 to 201810
# Successfully processed chunks 201810 to 201820
# Successfully processed chunks 201820 to 201830
# Successfully processed chunks 201830 to 201840
# Successfully processed chunks 201840 to 201850
# Successfully processed chunks 201850 to 201860
# Successfully processed chunks 201860 to 201870
# Successfully processed chunks 201870 to 201880
# Successfully processed chunks 201880 to 201890
# Successfully processed chunks 201890 to 201900
# Successfully processed chunks 201900 to 201910
# Successfully processed chunks 201910 to 201920
# Successfully processed chunks 201920 to 201930
# Successfully processed chunks 201930 to 201940
# Successfully processed chunks 201940 to 201950
# Successfully processed chunks 201950 to 201960
# Successfully processed chunks 201960 to 201970
# Successfully processed chunks 201970 to 201980
# Successfully processed chunks 201980 to 201990
# Successfully processed chunks 201990 to 202000
# Successfully processed chunks 202000 to 202010
# Successfully processed chunks 202010 to 202020
# Successfully processed chunks 202020 to 202030
# Successfully processed chunks 202030 to 202040
# Successfully processed chunks 202040 to 202050
# Successfully processed chunks 202050 to 202060
# Successfully processed chunks 202060 to 202070
# Successfully processed chunks 202070 to 202080
# Successfully processed chunks 202080 to 202090
# Successfully processed chunks 202090 to 202100
# Successfully processed chunks 202100 to 202110
# Successfully processed chunks 202110 to 202120
# Successfully processed chunks 202120 to 202130
# Successfully processed chunks 202130 to 202140
# Successfully processed chunks 202140 to 202150
# Successfully processed chunks 202150 to 202160
# Successfully processed chunks 202160 to 202170
# Successfully processed chunks 202170 to 202180
# Successfully processed chunks 202180 to 202190
# Successfully processed chunks 202190 to 202200
# Successfully processed chunks 202200 to 202210
# Successfully processed chunks 202210 to 202220
# Successfully processed chunks 202220 to 202230
# Successfully processed chunks 202230 to 202240
# Successfully processed chunks 202240 to 202250
# Successfully processed chunks 202250 to 202260
# Successfully processed chunks 202260 to 202270
# Successfully processed chunks 202270 to 202280
# Successfully processed chunks 202280 to 202290
# Successfully processed chunks 202290 to 202300
# Successfully processed chunks 202300 to 202310
# Successfully processed chunks 202310 to 202320
# Successfully processed chunks 202320 to 202330
# Successfully processed chunks 202330 to 202340
# Successfully processed chunks 202340 to 202350
# Successfully processed chunks 202350 to 202360
# Successfully processed chunks 202360 to 202370
# Successfully processed chunks 202370 to 202380
# Successfully processed chunks 202380 to 202390
# Successfully processed chunks 202390 to 202400
# Successfully processed chunks 202400 to 202410
# Successfully processed chunks 202410 to 202420
# Successfully processed chunks 202420 to 202430
# Successfully processed chunks 202430 to 202440
# Successfully processed chunks 202440 to 202450
# Successfully processed chunks 202450 to 202460
# Successfully processed chunks 202460 to 202470
# Successfully processed chunks 202470 to 202480
# Successfully processed chunks 202480 to 202490
# Successfully processed chunks 202490 to 202500
# Successfully processed chunks 202500 to 202510
# Successfully processed chunks 202510 to 202520
# Successfully processed chunks 202520 to 202530
# Successfully processed chunks 202530 to 202540
# Successfully processed chunks 202540 to 202550
# Successfully processed chunks 202550 to 202560
# Successfully processed chunks 202560 to 202570
# Successfully processed chunks 202570 to 202580
# Successfully processed chunks 202580 to 202590
# Successfully processed chunks 202590 to 202600
# Successfully processed chunks 202600 to 202610
# Successfully processed chunks 202610 to 202620
# Successfully processed chunks 202620 to 202630
# Successfully processed chunks 202630 to 202640
# Successfully processed chunks 202640 to 202650
# Successfully processed chunks 202650 to 202660
# Successfully processed chunks 202660 to 202670
# Successfully processed chunks 202670 to 202680
# Successfully processed chunks 202680 to 202690
# Successfully processed chunks 202690 to 202700
# Successfully processed chunks 202700 to 202710
# Successfully processed chunks 202710 to 202720
# Successfully processed chunks 202720 to 202730
# Successfully processed chunks 202730 to 202740
# Successfully processed chunks 202740 to 202750
# Successfully processed chunks 202750 to 202760
# Successfully processed chunks 202760 to 202770
# Successfully processed chunks 202770 to 202780
# Successfully processed chunks 202780 to 202790
# Successfully processed chunks 202790 to 202800
# Successfully processed chunks 202800 to 202810
# Successfully processed chunks 202810 to 202820
# Successfully processed chunks 202820 to 202830
# Successfully processed chunks 202830 to 202840
# Successfully processed chunks 202840 to 202850
# Successfully processed chunks 202850 to 202860
# Successfully processed chunks 202860 to 202870
# Successfully processed chunks 202870 to 202880
# Successfully processed chunks 202880 to 202890
# Successfully processed chunks 202890 to 202900
# Successfully processed chunks 202900 to 202910
# Successfully processed chunks 202910 to 202920
# Successfully processed chunks 202920 to 202930
# Successfully processed chunks 202930 to 202940
# Successfully processed chunks 202940 to 202950
# Successfully processed chunks 202950 to 202960
# Successfully processed chunks 202960 to 202970
# Successfully processed chunks 202970 to 202980
# Successfully processed chunks 202980 to 202990
# Successfully processed chunks 202990 to 203000
# Successfully processed chunks 203000 to 203010
# Successfully processed chunks 203010 to 203020
# Successfully processed chunks 203020 to 203030
# Successfully processed chunks 203030 to 203040
# Successfully processed chunks 203040 to 203050
# Successfully processed chunks 203050 to 203060
# Successfully processed chunks 203060 to 203070
# Successfully processed chunks 203070 to 203080
# Successfully processed chunks 203080 to 203090
# Successfully processed chunks 203090 to 203100
# Successfully processed chunks 203100 to 203110
# Successfully processed chunks 203110 to 203120
# Successfully processed chunks 203120 to 203130
# Successfully processed chunks 203130 to 203140
# Successfully processed chunks 203140 to 203150
# Successfully processed chunks 203150 to 203160
# Successfully processed chunks 203160 to 203170
# Successfully processed chunks 203170 to 203180
# Successfully processed chunks 203180 to 203190
# Successfully processed chunks 203190 to 203200
# Successfully processed chunks 203200 to 203210
# Successfully processed chunks 203210 to 203220
# Successfully processed chunks 203220 to 203230
# Successfully processed chunks 203230 to 203240
# Successfully processed chunks 203240 to 203250
# Successfully processed chunks 203250 to 203260
# Successfully processed chunks 203260 to 203270
# Successfully processed chunks 203270 to 203280
# Successfully processed chunks 203280 to 203290
# Successfully processed chunks 203290 to 203300
# Successfully processed chunks 203300 to 203310
# Successfully processed chunks 203310 to 203320
# Successfully processed chunks 203320 to 203330
# Successfully processed chunks 203330 to 203340
# Successfully processed chunks 203340 to 203350
# Successfully processed chunks 203350 to 203360
# Successfully processed chunks 203360 to 203370
# Successfully processed chunks 203370 to 203380
# Successfully processed chunks 203380 to 203390
# Successfully processed chunks 203390 to 203400
# Successfully processed chunks 203400 to 203410
# Successfully processed chunks 203410 to 203420
# Successfully processed chunks 203420 to 203430
# Successfully processed chunks 203430 to 203440
# Successfully processed chunks 203440 to 203450
# Successfully processed chunks 203450 to 203460
# Successfully processed chunks 203460 to 203470
# Successfully processed chunks 203470 to 203480
# Successfully processed chunks 203480 to 203490
# Successfully processed chunks 203490 to 203500
# Successfully processed chunks 203500 to 203510
# Successfully processed chunks 203510 to 203520
# Successfully processed chunks 203520 to 203530
# Successfully processed chunks 203530 to 203540
# Successfully processed chunks 203540 to 203550
# Successfully processed chunks 203550 to 203560
# Successfully processed chunks 203560 to 203570
# Successfully processed chunks 203570 to 203580
# Successfully processed chunks 203580 to 203590
# Successfully processed chunks 203590 to 203600
# Successfully processed chunks 203600 to 203610
# Successfully processed chunks 203610 to 203620
# Successfully processed chunks 203620 to 203630
# Successfully processed chunks 203630 to 203640
# Successfully processed chunks 203640 to 203650
# Successfully processed chunks 203650 to 203660
# Successfully processed chunks 203660 to 203670
# Successfully processed chunks 203670 to 203680
# Successfully processed chunks 203680 to 203690
# Successfully processed chunks 203690 to 203700
# Successfully processed chunks 203700 to 203710
# Successfully processed chunks 203710 to 203720
# Successfully processed chunks 203720 to 203730
# Successfully processed chunks 203730 to 203740
# Successfully processed chunks 203740 to 203750
# Successfully processed chunks 203750 to 203760
# Successfully processed chunks 203760 to 203770
# Successfully processed chunks 203770 to 203780
# Successfully processed chunks 203780 to 203790
# Successfully processed chunks 203790 to 203800
# Successfully processed chunks 203800 to 203810
# Successfully processed chunks 203810 to 203820
# Successfully processed chunks 203820 to 203830
# Successfully processed chunks 203830 to 203840
# Successfully processed chunks 203840 to 203850
# Successfully processed chunks 203850 to 203860
# Successfully processed chunks 203860 to 203870
# Successfully processed chunks 203870 to 203880
# Successfully processed chunks 203880 to 203890
# Successfully processed chunks 203890 to 203900
# Successfully processed chunks 203900 to 203910
# Successfully processed chunks 203910 to 203920
# Successfully processed chunks 203920 to 203930
# Successfully processed chunks 203930 to 203940
# Successfully processed chunks 203940 to 203950
# Successfully processed chunks 203950 to 203960
# Successfully processed chunks 203960 to 203970
# Successfully processed chunks 203970 to 203980
# Successfully processed chunks 203980 to 203990
# Successfully processed chunks 203990 to 204000
# Successfully processed chunks 204000 to 204010
# Successfully processed chunks 204010 to 204020
# Successfully processed chunks 204020 to 204030
# Successfully processed chunks 204030 to 204040
# Successfully processed chunks 204040 to 204050
# Successfully processed chunks 204050 to 204060
# Successfully processed chunks 204060 to 204070
# Successfully processed chunks 204070 to 204080
# Successfully processed chunks 204080 to 204090
# Successfully processed chunks 204090 to 204100
# Successfully processed chunks 204100 to 204110
# Successfully processed chunks 204110 to 204120
# Successfully processed chunks 204120 to 204130
# Successfully processed chunks 204130 to 204140
# Successfully processed chunks 204140 to 204150
# Successfully processed chunks 204150 to 204160
# Successfully processed chunks 204160 to 204170
# Successfully processed chunks 204170 to 204180
# Successfully processed chunks 204180 to 204190
# Successfully processed chunks 204190 to 204200
# Successfully processed chunks 204200 to 204210
# Successfully processed chunks 204210 to 204220
# Successfully processed chunks 204220 to 204230
# Successfully processed chunks 204230 to 204240
# Successfully processed chunks 204240 to 204250
# Successfully processed chunks 204250 to 204260
# Successfully processed chunks 204260 to 204270
# Successfully processed chunks 204270 to 204280
# Successfully processed chunks 204280 to 204290
# Successfully processed chunks 204290 to 204300
# Successfully processed chunks 204300 to 204310
# Successfully processed chunks 204310 to 204320
# Successfully processed chunks 204320 to 204330
# Successfully processed chunks 204330 to 204340
# Successfully processed chunks 204340 to 204350
# Successfully processed chunks 204350 to 204360
# Successfully processed chunks 204360 to 204370
# Successfully processed chunks 204370 to 204380
# Successfully processed chunks 204380 to 204390
# Successfully processed chunks 204390 to 204400
# Successfully processed chunks 204400 to 204410
# Successfully processed chunks 204410 to 204420
# Successfully processed chunks 204420 to 204430
# Successfully processed chunks 204430 to 204440
# Successfully processed chunks 204440 to 204450
# Successfully processed chunks 204450 to 204460
# Successfully processed chunks 204460 to 204470
# Successfully processed chunks 204470 to 204480
# Successfully processed chunks 204480 to 204490
# Successfully processed chunks 204490 to 204500
# Successfully processed chunks 204500 to 204510
# Successfully processed chunks 204510 to 204520
# Successfully processed chunks 204520 to 204530
# Successfully processed chunks 204530 to 204540
# Successfully processed chunks 204540 to 204550
# Successfully processed chunks 204550 to 204560
# Successfully processed chunks 204560 to 204570
# Successfully processed chunks 204570 to 204580
# Successfully processed chunks 204580 to 204590
# Successfully processed chunks 204590 to 204600
# Successfully processed chunks 204600 to 204610
# Successfully processed chunks 204610 to 204620
# Successfully processed chunks 204620 to 204630
# Successfully processed chunks 204630 to 204640
# Successfully processed chunks 204640 to 204650
# Successfully processed chunks 204650 to 204660
# Successfully processed chunks 204660 to 204670
# Successfully processed chunks 204670 to 204680
# Successfully processed chunks 204680 to 204690
# Successfully processed chunks 204690 to 204700
# Successfully processed chunks 204700 to 204710
# Successfully processed chunks 204710 to 204720
# Successfully processed chunks 204720 to 204730
# Successfully processed chunks 204730 to 204740
# Successfully processed chunks 204740 to 204750
# Successfully processed chunks 204750 to 204760
# Successfully processed chunks 204760 to 204770
# Successfully processed chunks 204770 to 204780
# Successfully processed chunks 204780 to 204790
# Successfully processed chunks 204790 to 204800
# Successfully processed chunks 204800 to 204810
# Successfully processed chunks 204810 to 204820
# Successfully processed chunks 204820 to 204830
# Successfully processed chunks 204830 to 204840
# Successfully processed chunks 204840 to 204850
# Successfully processed chunks 204850 to 204860
# Successfully processed chunks 204860 to 204870
# Successfully processed chunks 204870 to 204880
# Successfully processed chunks 204880 to 204890
# Successfully processed chunks 204890 to 204900
# Successfully processed chunks 204900 to 204910
# Successfully processed chunks 204910 to 204920
# Successfully processed chunks 204920 to 204930
# Successfully processed chunks 204930 to 204940
# Successfully processed chunks 204940 to 204950
# Successfully processed chunks 204950 to 204960
# Successfully processed chunks 204960 to 204970
# Successfully processed chunks 204970 to 204980
# Successfully processed chunks 204980 to 204990
# Successfully processed chunks 204990 to 205000
# Successfully processed chunks 205000 to 205010
# Successfully processed chunks 205010 to 205020
# Successfully processed chunks 205020 to 205030
# Successfully processed chunks 205030 to 205040
# ==== Ingestion Complete! Data saved permanently to disk ====

# %%
# Step 4: Link your local llama3.1 engine
retriever = db.as_retriever(search_kwargs={"k": 3})
llm = ChatOllama(model="qwen2.5:3b", temperature=0)

# %%
# Step 5: Augment the prompt and invoke

prompt = ChatPromptTemplate.from_template("""
أنت مساعد ذكي ومتخصص في تحليل النصوص العربية ومحدد جداً. مهمتك هي الإجابة على سؤال المستخدم بناءً على السياق المستخرج المقدم فقط.

شروط الإجابة:
1. يجب أن تعتمد إجابتك بالكامل على السياق المرفق أدناه.
2. لا تضف أي معلومات خارجية تماماً من خارج هذا النص.
3. يمكنك فهم المعنى المرادف لغوياً بدقة.
4. إذا لم تكن الإجابة واضحة بشكل مباشر، يجب عليك تحليل نص الكتب بدقة واستنباط الإجابة الصحيحة بناءً على الفهم والربط المنطقي بين الأفكار الواردة.
5. يجب عليك دائماً ذكر اسم الكتاب أو المصدر الذي استخرجت منه الإجابة في نهاية ردك.

السياق المستخرج:
{context}

السؤال:
{input}
""")


doc_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, doc_chain)

# %%
print("\n==== محرك البث الفوري جاهز تماماً! ====")
print("يمكنك البدء بطرح الأسئلة (اكتب 'خروج' للإنهاء):")
print("-" * 50)

while True:
    # 1. Continuously prompt the user for input
    user_question = input("\nYou: ")
    
    # 2. Check if the user wants to break out of the loop
    if user_question.lower() in ['exit', 'quit','خروج']:
        print("تم إغلاق البرنامج بنجاح.")
        break
        
    # 3. Skip empty submissions
    if not user_question.strip():
        continue
        
    # 4. Invoke the chain with the live user input
    try:
        response = rag_chain.invoke({"input": user_question})
        
        # 5. Extract and print the answer safely
        # Note: LangChain RAG chains usually return a dictionary. 
        # If yours returns a raw string instead, just use: print(f"AI: {response}")
        answer = response.get("answer", response) if isinstance(response, dict) else response
        print(f"AI: {answer}")
        
    except Exception as e:
        print(f"An error occurred: {e}")
