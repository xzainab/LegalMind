# %%
import os
import shutil
from pdf2image import pdfinfo_from_path, convert_from_path
from ocrmac import ocrmac

# Define main folder paths
INPUT_FOLDER = "./CBB_Documents"  # Root folder containing subfolders (2004, 2005, etc.)
OUTPUT_ROOT = "./ocr_results"               # Text files will mirror subfolders here
DONE_ROOT = "./processed_pdfs"              # Moved PDFs will mirror subfolders here

# Collect all PDF files across all subfolders first to get an accurate count
pdf_tasks = []
for root, dirs, files in os.walk(INPUT_FOLDER):
    for file in files:
        if file.lower().endswith(".pdf"):
            full_path = os.path.join(root, file)
            # Calculate the relative path from the input folder (e.g., "2004/doc.pdf")
            rel_path = os.path.relpath(full_path, INPUT_FOLDER)
            pdf_tasks.append((full_path, rel_path))

if not pdf_tasks:
    print(f"No PDF files found inside '{INPUT_FOLDER}' or its subfolders.")
    exit()

print(f"Found {len(pdf_tasks)} PDF(s) across all folders to process.\n" + "="*40)

# Loop through each PDF file task
for file_index, (pdf_path, rel_path) in enumerate(pdf_tasks, 1):
    file_name = os.path.basename(pdf_path)
    
    # Mirror the subfolder structure for outputs
    rel_dir = os.path.dirname(rel_path)
    current_output_dir = os.path.join(OUTPUT_ROOT, rel_dir)
    current_done_dir = os.path.join(DONE_ROOT, rel_dir)
    
    # Ensure destination subfolders exist
    os.makedirs(current_output_dir, exist_ok=True)
    os.makedirs(current_done_dir, exist_ok=True)
    
    # Define exact output targets
    txt_name = os.path.splitext(file_name)[0] + ".txt"
    output_txt_path = os.path.join(current_output_dir, txt_name)
    destination_pdf_path = os.path.join(current_done_dir, file_name)
         
    print(f"\n[{file_index}/{len(pdf_tasks)}] Processing: {rel_path}")
         
    try:
        # Get total page count
        info = pdfinfo_from_path(pdf_path)
        total_pages = info["Pages"]
        print(f"-> Total pages: {total_pages}")
    except Exception as e:
        print(f"-> Error reading PDF info for {file_name}: {e}. Skipping file.")
        continue

    # Open the specific output file for this PDF
    with open(output_txt_path, "w", encoding="utf-8") as f:
        # Process page by page
        for i in range(1, total_pages + 1):
            print(f"   Processing page {i}/{total_pages}...")
                         
            # Convert ONLY the current page into memory
            try:
                single_page_list = convert_from_path(
                    pdf_path, 
                    dpi=300, 
                    first_page=i, 
                    last_page=i
                )
            except Exception as e:
                print(f"   Error converting page {i}: {e}")
                continue
                             
            if not single_page_list:
                continue
                             
            page_image = single_page_list[0]
            temp_img_path = f"temp_page_{file_index}_{i}.png"
                         
            # Save single page to disk
            page_image.save(temp_img_path, "PNG")
                         
            # Run Apple Vision OCR
            try:
                annotations = ocrmac.OCR(
                    temp_img_path, 
                    language_preference=['ar-SA'], 
                    recognition_level='accurate'
                ).recognize()
                                 
                # Extract text
                text_blocks = []
                for item in annotations:
                    if isinstance(item, (list, tuple)) and len(item) > 0:
                        text_blocks.append(str(item[0]))
                    else:
                        text_blocks.append(str(item))
                page_text = "\n".join(text_blocks)
                                 
                # Write immediately to file
                f.write(f"--- Page {i} ---\n")
                f.write(page_text)
                f.write("\n\n")
                             
            except Exception as e:
                print(f"   OCR Error on page {i}: {e}")
                             
            finally:
                # Clean up memory and file immediately
                del page_image
                del single_page_list
                if os.path.exists(temp_img_path):
                    os.remove(temp_img_path)

    print(f"-> Finished OCR! Saved to {output_txt_path}")

    # Move the PDF file to its respective processed subfolder
    try:
        shutil.move(pdf_path, destination_pdf_path)
        print(f"-> Moved PDF to {destination_pdf_path}")
    except Exception as e:
        print(f"-> Error moving {file_name}: {e}")

print("\n" + "="*40 + "\nAll folders and subfolders processed successfully!")
# Out:
# No PDF files found inside './CBB_Documents' or its subfolders.
# Found 0 PDF(s) across all folders to process.
# ========================================
#
# ========================================
# All folders and subfolders processed successfully!

# %%
import os
import shutil
from pdf2image import pdfinfo_from_path, convert_from_path
from ocrmac import ocrmac

# Define main folder paths
INPUT_FOLDER = "./هيئة التشريع و الرأي القانوني"  # Root folder containing arbitrary subfolders
DONE_ROOT = "./processed_pdfs"     # Moved PDFs will mirror subfolders here

# Collect all PDF files across all subfolders
pdf_tasks = []
for root, dirs, files in os.walk(INPUT_FOLDER):
    for file in files:
        if file.lower().endswith(".pdf"):
            full_path = os.path.join(root, file)
            # Calculate the relative path from the input folder
            rel_path = os.path.relpath(full_path, INPUT_FOLDER)
            pdf_tasks.append((full_path, rel_path))

if not pdf_tasks:
    print(f"No PDF files found inside '{INPUT_FOLDER}' or its subfolders.")
    exit()

print(f"Found {len(pdf_tasks)} PDF(s) across all folders to process.\n" + "="*40)

# Loop through each PDF file task
for file_index, (pdf_path, rel_path) in enumerate(pdf_tasks, 1):
    file_name = os.path.basename(pdf_path)
    
    # 1. Output TXT goes directly into the PDF's current directory
    current_output_dir = os.path.dirname(pdf_path)
    
    # 2. Destination directory for moving the processed PDF
    rel_dir = os.path.dirname(rel_path)
    current_done_dir = os.path.join(DONE_ROOT, rel_dir)
    os.makedirs(current_done_dir, exist_ok=True)
    
    # Define file target paths
    txt_name = os.path.splitext(file_name)[0] + ".txt"
    output_txt_path = os.path.join(current_output_dir, txt_name)
    destination_pdf_path = os.path.join(current_done_dir, file_name)
         
    print(f"\n[{file_index}/{len(pdf_tasks)}] Processing: {rel_path}")
         
    try:
        # Get total page count
        info = pdfinfo_from_path(pdf_path)
        total_pages = info["Pages"]
        print(f"-> Total pages: {total_pages}")
    except Exception as e:
        print(f"-> Error reading PDF info for {file_name}: {e}. Skipping file.")
        continue

    # Open the output text file inside the same folder as the PDF
    with open(output_txt_path, "w", encoding="utf-8") as f:
        for i in range(1, total_pages + 1):
            print(f"   Processing page {i}/{total_pages}...")
                         
            try:
                single_page_list = convert_from_path(
                    pdf_path, 
                    dpi=300, 
                    first_page=i, 
                    last_page=i
                )
            except Exception as e:
                print(f"   Error converting page {i}: {e}")
                continue
                             
            if not single_page_list:
                continue
                             
            page_image = single_page_list[0]
            temp_img_path = f"temp_page_{file_index}_{i}.png"
                         
            # Save temporary page image to disk
            page_image.save(temp_img_path, "PNG")
                         
            # Run Apple Vision OCR
            try:
                annotations = ocrmac.OCR(
                    temp_img_path, 
                    language_preference=['ar-SA'], 
                    recognition_level='accurate'
                ).recognize()
                                 
                # Extract text lines
                text_blocks = []
                for item in annotations:
                    if isinstance(item, (list, tuple)) and len(item) > 0:
                        text_blocks.append(str(item[0]))
                    else:
                        text_blocks.append(str(item))
                page_text = "\n".join(text_blocks)
                                 
                # Write page content to output .txt file
                f.write(f"--- Page {i} ---\n")
                f.write(page_text)
                f.write("\n\n")
                             
            except Exception as e:
                print(f"   OCR Error on page {i}: {e}")
                             
            finally:
                # Cleanup temporary image file and memory
                del page_image
                del single_page_list
                if os.path.exists(temp_img_path):
                    os.remove(temp_img_path)

    print(f"-> Finished OCR! Saved text file to: {output_txt_path}")

    # Move processed PDF out to its corresponding directory in processed_pdfs
    try:
        shutil.move(pdf_path, destination_pdf_path)
        print(f"-> Moved PDF to: {destination_pdf_path}")
    except Exception as e:
        print(f"-> Error moving {file_name}: {e}")

print("\n" + "="*40 + "\nAll folders and subfolders processed successfully!")
# Out:
# Found 701 PDF(s) across all folders to process.
# ========================================
#
# [1/701] Processing: المعاهدات/الجمارك/قانون رقم (2).pdf
# -> Total pages: 54
#    Processing page 1/54...
#    Processing page 2/54...
#    Processing page 3/54...
#    Processing page 4/54...
#    Processing page 5/54...
#    Processing page 6/54...
#    Processing page 7/54...
#    Processing page 8/54...
#    Processing page 9/54...
#    Processing page 10/54...
#    Processing page 11/54...
#    Processing page 12/54...
#    Processing page 13/54...
#    Processing page 14/54...
#    Processing page 15/54...
#    Processing page 16/54...
#    Processing page 17/54...
#    Processing page 18/54...
#    Processing page 19/54...
#    Processing page 20/54...
#    Processing page 21/54...
#    Processing page 22/54...
#    Processing page 23/54...
#    Processing page 24/54...
#    Processing page 25/54...
#    Processing page 26/54...
#    Processing page 27/54...
#    Processing page 28/54...
#    Processing page 29/54...
#    Processing page 30/54...
#    Processing page 31/54...
#    Processing page 32/54...
#    Processing page 33/54...
#    Processing page 34/54...
#    Processing page 35/54...
#    Processing page 36/54...
#    Processing page 37/54...
#    Processing page 38/54...
#    Processing page 39/54...
#    Processing page 40/54...
#    Processing page 41/54...
#    Processing page 42/54...
#    Processing page 43/54...
#    Processing page 44/54...
#    Processing page 45/54...
#    Processing page 46/54...
#    Processing page 47/54...
#    Processing page 48/54...
#    Processing page 49/54...
#    Processing page 50/54...
#    Processing page 51/54...
#    Processing page 52/54...
#    Processing page 53/54...
#    Processing page 54/54...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/قانون رقم (2).txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/قانون رقم (2).pdf
#
# [2/701] Processing: المعاهدات/الجمارك/مرسوم رقم (81).pdf
# -> Total pages: 682
#    Processing page 1/682...
#    Processing page 2/682...
#    Processing page 3/682...
#    Processing page 4/682...
#    Processing page 5/682...
#    Processing page 6/682...
#    Processing page 7/682...
#    Processing page 8/682...
#    Processing page 9/682...
#    Processing page 10/682...
#    Processing page 11/682...
#    Processing page 12/682...
#    Processing page 13/682...
#    Processing page 14/682...
#    Processing page 15/682...
#    Processing page 16/682...
#    Processing page 17/682...
#    Processing page 18/682...
#    Processing page 19/682...
#    Processing page 20/682...
#    Processing page 21/682...
#    Processing page 22/682...
#    Processing page 23/682...
#    Processing page 24/682...
#    Processing page 25/682...

# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم رقم (81).txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم رقم (81).pdf
#
# [3/701] Processing: المعاهدات/الجمارك/مرسوم رقم (19) لسنة 2020.pdf
# -> Total pages: 6
#    Processing page 1/6...
#    Processing page 2/6...
#    Processing page 3/6...
#    Processing page 4/6...
#    Processing page 5/6...
#    Processing page 6/6...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم رقم (19) لسنة 2020.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم رقم (19) لسنة 2020.pdf
#
# [4/701] Processing: المعاهدات/الجمارك/قانون رقم (9) لسنة 2018.pdf
# -> Total pages: 16
#    Processing page 1/16...
#    Processing page 2/16...
#    Processing page 3/16...
#    Processing page 4/16...
#    Processing page 5/16...
#    Processing page 6/16...
#    Processing page 7/16...
#    Processing page 8/16...
#    Processing page 9/16...
#    Processing page 10/16...
#    Processing page 11/16...
#    Processing page 12/16...
#    Processing page 13/16...
#    Processing page 14/16...
#    Processing page 15/16...
#    Processing page 16/16...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/قانون رقم (9) لسنة 2018.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/قانون رقم (9) لسنة 2018.pdf
#
# [5/701] Processing: المعاهدات/الجمارك/مرسوم 27.pdf
# -> Total pages: 1
#    Processing page 1/1...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم 27.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم 27.pdf
#
# [6/701] Processing: المعاهدات/الجمارك/مرسوم رقم (41) لسنة 2.pdf
# -> Total pages: 3
#    Processing page 1/3...
#    Processing page 2/3...
#    Processing page 3/3...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم رقم (41) لسنة 2.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم رقم (41) لسنة 2.pdf
#
# [7/701] Processing: المعاهدات/الجمارك/مرسوم رقم (40) لسنة 2011.pdf
# -> Total pages: 14
#    Processing page 1/14...
#    Processing page 2/14...
#    Processing page 3/14...
#    Processing page 4/14...
#    Processing page 5/14...
#    Processing page 6/14...
#    Processing page 7/14...
#    Processing page 8/14...
#    Processing page 9/14...
#    Processing page 10/14...
#    Processing page 11/14...
#    Processing page 12/14...
#    Processing page 13/14...
#    Processing page 14/14...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم رقم (40) لسنة 2011.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم رقم (40) لسنة 2011.pdf
#
# [8/701] Processing: المعاهدات/الجمارك/مرسوم بقانون رقم (13).pdf
# -> Total pages: 8
#    Processing page 1/8...
#    Processing page 2/8...
#    Processing page 3/8...
#    Processing page 4/8...
#    Processing page 5/8...
#    Processing page 6/8...
#    Processing page 7/8...
#    Processing page 8/8...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم بقانون رقم (13).txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات
t
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم بقانون رقم (10).pdf
#
# [16/701] Processing: المعاهدات/الجمارك/مرسوم بقانون رقم (27).pdf
# -> Total pages: 17
#    Processing page 1/17...
#    Processing page 2/17...
#    Processing page 3/17...
#    Processing page 4/17...
#    Processing page 5/17...
#    Processing page 6/17...
#    Processing page 7/17...
#    Processing page 8/17...
#    Processing page 9/17...
#    Processing page 10/17...
#    Processing page 11/17...
#    Processing page 12/17...
#    Processing page 13/17...
#    Processing page 14/17...
#    Processing page 15/17...
#    Processing page 16/17...
#    Processing page 17/17...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/مرسوم بقانون رقم (27).txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/مرسوم بقانون رقم (27).pdf
#
# [17/701] Processing: المعاهدات/الجمارك/قانون رقم (13) لسنة 2014.pdf
# -> Total pages: 34
#    Processing page 1/34...
#    Processing page 2/34...
#    Processing page 3/34...
#    Processing page 4/34...
#    Processing page 5/34...
#    Processing page 6/34...
#    Processing page 7/34...
#    Processing page 8/34...
#    Processing page 9/34...
#    Processing page 10/34...
#    Processing page 11/34...
#    Processing page 12/34...
#    Processing page 13/34...
#    Processing page 14/34...
#    Processing page 15/34...
#    Processing page 16/34...
#    Processing page 17/34...
#    Processing page 18/34...
#    Processing page 19/34...
#    Processing page 20/34...
#    Processing page 21/34...
#    Processing page 22/34...
#    Processing page 23/34...
#    Processing page 24/34...
#    Processing page 25/34...
#    Processing page 26/34...
#    Processing page 27/34...
#    Processing page 28/34...
#    Processing page 29/34...
#    Processing page 30/34...
#    Processing page 31/34...
#    Processing page 32/34...
#    Processing page 33/34...
#    Processing page 34/34...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/الجمارك/قانون رقم (13) لسنة 2014.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/الجمارك/قانون رقم (13) لسنة 2014.pdf
#
# [18/701] Processing: المعاهدات/النقل البري/مرسوم بقانون رقم (٢١) لسنة ١٩٨١.pdf
# -> Total pages: 3
#    Processing page 1/3...
#    Processing page 2/3...
#    Processing page 3/3...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/النقل البري/مرسوم بقانون رقم (٢١) لسنة ١٩٨١.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/مرسوم بقانون رقم (٢١) لسنة ١٩٨١.pdf
#
# [19/701] Processing: المعاهدات/النقل البري/قانون رقم (20) لسنة 2012.pdf
# -> Total pages: 11
#    Processing page 1/11...
#    Processing page 2/11...
#    Processing page 3/11...
#    Processing page 4/11...
#    Processing page 5/11...
#    Processing page 6/11...
#    Processing page 7/11...
#    Processing page 8/11...
#    Processing page 9/11...
#    Processing page 10/11...
#    Processing page 11/11...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/النقل البري/قانون رقم (20) لسنة 2012.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/قانون رقم (20) لسنة 2012.pdf
#
# [20/701] Processing: المعاهدات/النقل البري/قانون رقم (٨) لسنة ١٩٨٥.pdf
# -> Total pages: 3
#    Processing page 1/3...
#    Processing page 2/3...
#    Processing page 3/3...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/النقل البري/قانون رقم (٨) لسنة ١٩٨٥.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/قانون رقم (٨) لسنة ١٩٨٥.pdf
#
# [21/701] Processing: المعاهدات/النقل البري/مرسوم بقانون رقم (٧٩) لسنة ٢٠٠٦.pdf
# -> Total pages: 10
#    Processing page 1/10...
#    Processing page 2/10...
#    Processing page 3/10...
#    Processing page 4/10...
#    Processing page 5/10...
#    Processing page 6/10...
#    Processing page 7/10...
#    Processing page 8/10...
#    Processing page 9/10...
#    Processing page 10/10...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات
txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/مرسوم بقانون رقم (٤) لسنة ١٩٨٦.pdf
#
# [28/701] Processing: المعاهدات/النقل البري/قانون رقم (2) لسنة 2011.pdf
# -> Total pages: 32
#    Processing page 1/32...
#    Processing page 2/32...
#    Processing page 3/32...
#    Processing page 4/32...
#    Processing page 5/32...
#    Processing page 6/32...
#    Processing page 7/32...
#    Processing page 8/32...
#    Processing page 9/32...
#    Processing page 10/32...
#    Processing page 11/32...
#    Processing page 12/32...
#    Processing page 13/32...
#    Processing page 14/32...
#    Processing page 15/32...
#    Processing page 16/32...
#    Processing page 17/32...
#    Processing page 18/32...
#    Processing page 19/32...
#    Processing page 20/32...
#    Processing page 21/32...
#    Processing page 22/32...
#    Processing page 23/32...
#    Processing page 24/32...
#    Processing page 25/32...
#    Processing page 26/32...
#    Processing page 27/32...
#    Processing page 28/32...
#    Processing page 29/32...
#    Processing page 30/32...
#    Processing page 31/32...
#    Processing page 32/32...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/النقل البري/قانون رقم (2) لسنة 2011.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/قانون رقم (2) لسنة 2011.pdf
#
# [29/701] Processing: المعاهدات/النقل البري/قانون رقم (٣٠) لسنة ٢٠٠٦.pdf
# -> Total pages: 40
#    Processing page 1/40...
#    Processing page 2/40...
#    Processing page 3/40...
#    Processing page 4/40...
#    Processing page 5/40...
#    Processing page 6/40...
#    Processing page 7/40...
#    Processing page 8/40...
#    Processing page 9/40...
#    Processing page 10/40...
#    Processing page 11/40...
#    Processing page 12/40...
#    Processing page 13/40...
#    Processing page 14/40...
#    Processing page 15/40...
#    Processing page 16/40...
#    Processing page 17/40...
#    Processing page 18/40...
#    Processing page 19/40...
#    Processing page 20/40...
#    Processing page 21/40...
#    Processing page 22/40...
#    Processing page 23/40...
#    Processing page 24/40...
#    Processing page 25/40...
#    Processing page 26/40...
#    Processing page 27/40...
#    Processing page 28/40...
#    Processing page 29/40...
#    Processing page 30/40...
#    Processing page 31/40...
#    Processing page 32/40...
#    Processing page 33/40...
#    Processing page 34/40...
#    Processing page 35/40...
#    Processing page 36/40...
#    Processing page 37/40...
#    Processing page 38/40...
#    Processing page 39/40...
#    Processing page 40/40...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/النقل البري/قانون رقم (٣٠) لسنة ٢٠٠٦.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/قانون رقم (٣٠) لسنة ٢٠٠٦.pdf
#
# [30/701] Processing: المعاهدات/النقل البري/قانون رقم (٢٥) لسنة ٢٠٠٥.pdf
# -> Total pages: 12
#    Processing page 1/12...
#    Processing page 2/12...
#    Processing page 3/12...
#    Processing page 4/12...
#    Processing page 5/12...
#    Processing page 6/12...
#    Processing page 7/12...
#    Processing page 8/12...
#    Processing page 9/12...
#    Processing page 10/12...
#    Processing page 11/12...
#    Processing page 12/12...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/النقل البري/قانون رقم (٢٥) لسنة ٢٠٠٥.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/النقل البري/قانون رقم (٢٥) لسنة ٢٠٠٥.pdf
#
# [31/701] Processing: المعاهدات/النقل البري/قانون رقم (13) لسنة 2011.pdf
# -> Total pages: 11
#    Processing page 1/11...
#    Processing page 2/11...
#    Processing page 3/11...
#    Processing page 4/11...
#    Processing page 5/11...
#    Processing page 6/11...
#    Processing page 7/11...
#    Processing page 8/11...
#    Processing page 9/11...
#    Processing page 10/11...
#    Processing page 11/11...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات

# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/البيئة/قانون رقم (13) لسنة 2019.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/البيئة/قانون رقم (13) لسنة 2019.pdf
#
# [428/701] Processing: المعاهدات/البيئة/قانون رقم (45) لسنة 2005.pdf
# -> Total pages: 24
#    Processing page 1/24...
#    Processing page 2/24...
#    Processing page 3/24...
#    Processing page 4/24...
#    Processing page 5/24...
#    Processing page 6/24...
#    Processing page 7/24...
#    Processing page 8/24...
#    Processing page 9/24...
#    Processing page 10/24...
#    Processing page 11/24...
#    Processing page 12/24...
#    Processing page 13/24...
#    Processing page 14/24...
#    Processing page 15/24...
#    Processing page 16/24...
#    Processing page 17/24...
#    Processing page 18/24...
#    Processing page 19/24...
#    Processing page 20/24...
#    Processing page 21/24...
#    Processing page 22/24...
#    Processing page 23/24...
#    Processing page 24/24...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/البيئة/قانون رقم (45) لسنة 2005.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/البيئة/قانون رقم (45) لسنة 2005.pdf
#
# [429/701] Processing: المعاهدات/البيئة/قانون رقم (27) لسنة 2012.pdf
# -> Total pages: 31
#    Processing page 1/31...
#    Processing page 2/31...
#    Processing page 3/31...
#    Processing page 4/31...
#    Processing page 5/31...
#    Processing page 6/31...
#    Processing page 7/31...
#    Processing page 8/31...
#    Processing page 9/31...
#    Processing page 10/31...
#    Processing page 11/31...
#    Processing page 12/31...
#    Processing page 13/31...
#    Processing page 14/31...
#    Processing page 15/31...
#    Processing page 16/31...
#    Processing page 17/31...
#    Processing page 18/31...
#    Processing page 19/31...
#    Processing page 20/31...
#    Processing page 21/31...
#    Processing page 22/31...
#    Processing page 23/31...
#    Processing page 24/31...
#    Processing page 25/31...
#    Processing page 26/31...
#    Processing page 27/31...
#    Processing page 28/31...
#    Processing page 29/31...
#    Processing page 30/31...
#    Processing page 31/31...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/البيئة/قانون رقم (27) لسنة 2012.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/البيئة/قانون رقم (27) لسنة 2012.pdf
#
# [430/701] Processing: المعاهدات/البيئة/قانون رقم (32) لسنة 2013.pdf
# -> Total pages: 6
#    Processing page 1/6...
#    Processing page 2/6...
#    Processing page 3/6...
#    Processing page 4/6...
#    Processing page 5/6...
#    Processing page 6/6...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/البيئة/قانون رقم (32) لسنة 2013.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/البيئة/قانون رقم (32) لسنة 2013.pdf
#
# [431/701] Processing: المعاهدات/البيئة/مرسوم بقانون رقم (41) لسنة 2000.pdf
# -> Total pages: 20
#    Processing page 1/20...
#    Processing page 2/20...
#    Processing page 3/20...
#    Processing page 4/20...
#    Processing page 5/20...
#    Processing page 6/20...
#    Processing page 7/20...
#    Processing page 8/20...
#    Processing page 9/20...
#    Processing page 10/20...
#    Processing page 11/20...
#    Processing page 12/20...
#    Processing page 13/20...
#    Processing page 14/20...
#    Processing page 15/20...
#    Processing page 16/20...
#    Processing page 17/20...
#    Processing page 18/20...
#    Processing page 19/20...
#    Processing page 20/20...
# -> Finished OCR! Saved text file to: ./هيئة التشريع و الرأي القانوني/المعاهدات/البيئة/مرسوم بقانون رقم (41) لسنة 2000.txt
# -> Moved PDF to: ./processed_pdfs/المعاهدات/البيئة/مرسوم بقانون رقم (41) لسنة 2000.pdf
#
# [432/701] Processing: المعاهدات/البيئة/قانون رقم (32) لسنة 2005.pdf
# -> Total pages: 530
#    Processing page 1/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 2/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 3/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 4/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 5/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 6/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 7/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 8/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 9/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 10/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 11/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 12/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
#    Processing page 13/530...
# /Users/zainababdulwahab/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/PIL/Image.py:3368: DecompressionBombWarning: Image size (136003200 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 109
#     105                 # Cleanup temporary image file and memory
#     106                 del page_image
#     107                 del single_page_list
#     108                 if os.path.exists(temp_img_path):
# --> 109                     os.remove(temp_img_path)
#     110
#     111     print(f"-> Finished OCR! Saved text file to: {output_txt_path}")
#     112
#
# File ~/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/ocrmac/ocrmac.py:342, in OCR.recognize(self, px)
#     338 def recognize(
#     339     self, px=False
#     340 ) -> List[Tuple[str, float, Tuple[float, float, float, float]]]:
#     341     if self.framework == "vision":
# --> 342         res = text_from_image(
#     343             self.image, self.recognition_level, self.language_preference, self.confidence_threshold, detail=self.detail
#     344         )
#     345     elif self.framework == "livetext":
#     346         res = livetext_from_image(
#     347             self.image, self.language_preference, detail=self.detail, unit=self.unit
#     348         )
#
# File ~/GA_DSB/ga_dsb_env/lib/python3.12/site-packages/ocrmac/ocrmac.py:160, in text_from_image(image, recognition_level, language_preference, confidence_threshold, detail)
#     154     req.setRecognitionLanguages_(language_preference)
#     156 handler = Vision.VNImageRequestHandler.alloc().initWithData_options_(
#     157     pil2buf(image), None
#     158 )
# --> 160 ret = handler.performRequests_error_([req], None)
#     161 # PyObjC returns either a bool or a (bool, NSError|None) tuple depending on the signature mapping.
#     162 if isinstance(ret, tuple):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/copy.py:61, in copy(x)
#      57 error = Error   # backward compatibility
#      59 __all__ = ["Error", "copy", "deepcopy"]
# ---> 61 def copy(x):
#      62     """Shallow copy operation on arbitrary Python objects.
#      63
#      64     See the module's __doc__ string for more info.
#      65     """
#      67     cls = type(x)
#
# KeyboardInterrupt:

# %%
import os
import shutil
import subprocess
from PIL import Image
from pdf2image import pdfinfo_from_path, convert_from_path
from ocrmac import ocrmac
import docx

# Disable PIL decompression bomb protection for high-resolution PDF pages
Image.MAX_IMAGE_PIXELS = None

# Define main folder paths
INPUT_FOLDER = "./هيئة التشريع والرأي القانوني"
DONE_ROOT = "./processed_pdfs"

# Supported Word formats
WORD_EXTENSIONS = ('.doc', '.docx')

def extract_text_from_docx(docx_path):
    """Extracts all text from paragraphs and tables in a .docx file."""
    doc = docx.Document(docx_path)
    full_text = []
    
    # Extract paragraph text
    for para in doc.paragraphs:
        if para.text.strip():
            full_text.append(para.text)
            
    # Extract text inside tables
    for table in doc.tables:
        for row in table.rows:
            row_text = [cell.text.strip() for cell in row.cells if cell.text.strip()]
            if row_text:
                full_text.append(" | ".join(row_text))
                
    return "\n".join(full_text)

def convert_doc_to_docx_mac(doc_path):
    """Converts legacy .doc to .docx using macOS native textutil tool."""
    cmd = ["textutil", "-convert", "docx", doc_path]
    subprocess.run(cmd, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    return os.path.splitext(doc_path)[0] + ".docx"


# Collect all PDF and Word files across all subfolders
tasks = []
for root, dirs, files in os.walk(INPUT_FOLDER):
    for file in files:
        ext = os.path.splitext(file)[1].lower()
        if ext == ".pdf" or ext in WORD_EXTENSIONS:
            full_path = os.path.join(root, file)
            rel_path = os.path.relpath(full_path, INPUT_FOLDER)
            tasks.append((full_path, rel_path, ext))

if not tasks:
    print(f"No PDF or Word files found inside '{INPUT_FOLDER}' or its subfolders.")
    exit()

print(f"Found {len(tasks)} file(s) across all folders to process.\n" + "="*40)

# Loop through each file task
for file_index, (file_path, rel_path, ext) in enumerate(tasks, 1):
    file_name = os.path.basename(file_path)
    current_output_dir = os.path.dirname(file_path)
    
    rel_dir = os.path.dirname(rel_path)
    current_done_dir = os.path.join(DONE_ROOT, rel_dir)
    os.makedirs(current_done_dir, exist_ok=True)
    
    txt_name = os.path.splitext(file_name)[0] + ".txt"
    output_txt_path = os.path.join(current_output_dir, txt_name)
    destination_file_path = os.path.join(current_done_dir, file_name)
    
    print(f"\n[{file_index}/{len(tasks)}] Processing ({ext}): {rel_path}")

    # ==========================================
    # BRANCH 1: WORD DOCUMENTS (.doc / .docx)
    # ==========================================
    if ext in WORD_EXTENSIONS:
        temp_created_docx = None
        target_docx_path = file_path

        try:
            # If legacy .doc, convert to temporary .docx via macOS textutil
            if ext == ".doc":
                print(" -> Converting legacy .doc to .docx via textutil...")
                target_docx_path = convert_doc_to_docx_mac(file_path)
                temp_created_docx = target_docx_path

            # Extract text
            extracted_text = extract_text_from_docx(target_docx_path)
            
            # Save output text file
            with open(output_txt_path, "w", encoding="utf-8") as f:
                f.write(extracted_text)
                
            print(f"-> Saved text file to: {output_txt_path}")

        except Exception as e:
            print(f"-> Error processing Word file {file_name}: {e}. Skipping file.")
            continue
        finally:
            # Clean up temporary converted docx file if created
            if temp_created_docx and os.path.exists(temp_created_docx):
                os.remove(temp_created_docx)

    # ==========================================
    # BRANCH 2: PDF DOCUMENTS (OCR)
    # ==========================================
    elif ext == ".pdf":
        try:
            info = pdfinfo_from_path(file_path)
            total_pages = info["Pages"]
            print(f"-> Total pages: {total_pages}")
        except Exception as e:
            print(f"-> Error reading PDF info for {file_name}: {e}. Skipping file.")
            continue

        with open(output_txt_path, "w", encoding="utf-8") as f:
            for i in range(1, total_pages + 1):
                print(f"   Processing page {i}/{total_pages}...")
                
                try:
                    single_page_list = convert_from_path(
                        file_path, 
                        dpi=200, 
                        first_page=i, 
                        last_page=i
                    )
                except Exception as e:
                    print(f"   Error converting page {i}: {e}")
                    continue
                
                if not single_page_list:
                    continue
                
                page_image = single_page_list[0]
                temp_img_path = f"temp_page_{file_index}_{i}.png"
                page_image.save(temp_img_path, "PNG")
                
                try:
                    annotations = ocrmac.OCR(
                        temp_img_path, 
                        language_preference=['ar-SA'], 
                        recognition_level='accurate'
                    ).recognize()
                    
                    text_blocks = []
                    for item in annotations:
                        if isinstance(item, (list, tuple)) and len(item) > 0:
                            text_blocks.append(str(item[0]))
                        else:
                            text_blocks.append(str(item))
                    page_text = "\n".join(text_blocks)
                    
                    f.write(f"--- Page {i} ---\n")
                    f.write(page_text)
                    f.write("\n\n")
                    
                except Exception as e:
                    print(f"   OCR Error on page {i}: {e}")
                finally:
                    del page_image
                    del single_page_list
                    if os.path.exists(temp_img_path):
                        os.remove(temp_img_path)

        print(f"-> Finished OCR! Saved text file to: {output_txt_path}")

    # Move processed file to DONE_ROOT
    try:
        shutil.move(file_path, destination_file_path)
        print(f"-> Moved original file to: {destination_file_path}")
    except Exception as e:
        print(f"-> Error moving {file_name}: {e}")

print("\n" + "="*40 + "\nAll files processed successfully!")
# Out:
# Found 59 file(s) across all folders to process.
# ========================================
#
# [1/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (3) لسنة 2000.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (3) لسنة 2000.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (3) لسنة 2000.docx
#
# [2/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 2001.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 2001.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 2001.docx
#
# [3/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1996.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1996.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1996.docx
#
# [4/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 1995.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 1995.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 1995.docx
#
# [5/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم 37 لسنة 1981 بتعيين موثق.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم 37 لسنة 1981 بتعيين موثق.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم 37 لسنة 1981 بتعيين موثق.docx
#
# [6/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 30 ) لسنة 1999.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 30 ) لسنة 1999.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 30 ) لسنة 1999.docx
#
# [7/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1997.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1997.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1997.docx
#
# [8/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/أمر أميري رقم (36) لسنة 2000.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/أمر أميري رقم (36) لسنة 2000.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/أمر أميري رقم (36) لسنة 2000.docx
#
# [9/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1982 بتشكيل لجنة مراقبة المطبوعات.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1982 بتشكيل لجنة مراقبة المطبوعات.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1982 بتشكيل لجنة مراقبة المطبوعات.docx
#
# [10/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1984.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1984.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1984.docx
#
# [11/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1987.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1987.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1987.docx
#
# [12/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1997 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1997 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1997 (1).docx
#
# [13/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1972 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1972 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1972 (1).docx
#
# [14/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (19) لسنة 1993.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (19) لسنة 1993.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (19) لسنة 1993.docx
#
# [15/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1980.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1980.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1980.docx
#
# [16/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1979.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1979.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1979.docx
#
# [17/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (8) لسنة 1993.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (8) لسنة 1993.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (8) لسنة 1993.docx
#
# [18/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/أمر أميري رقم (29) لسنة 2000.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/أمر أميري رقم (29) لسنة 2000.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/أمر أميري رقم (29) لسنة 2000.docx
#
# [19/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1987.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1987.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1987.docx
#
# [20/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 4 ) لسنة 2000.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 4 ) لسنة 2000.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 4 ) لسنة 2000.docx
#
# [21/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (17) لسنة 1989.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (17) لسنة 1989.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (17) لسنة 1989.docx
#
# [22/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1972.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1972.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1972.docx
#
# [23/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1991.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1991.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1991.docx
#
# [24/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1983.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1983.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1983.docx
#
# [25/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1996.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1996.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1996.docx
#
# [26/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 2001.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 2001.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 2001.docx
#
# [27/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1982.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1982.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1982.docx
#
# [28/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1981.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1981.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1981.docx
#
# [29/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 11 ) لسنة 1988.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 11 ) لسنة 1988.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 11 ) لسنة 1988.docx
#
# [30/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1998.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1998.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1998.docx
#
# [31/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1978.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1978.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 1 ) لسنة 1978.docx
#
# [32/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 1995 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 1995 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 1995 (1).docx
#
# [33/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1)   لسنة 1988.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1)   لسنة 1988.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1)   لسنة 1988.docx
#
# [34/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (19) لسنة 1993 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (19) لسنة 1993 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (19) لسنة 1993 (1).docx
#
# [35/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (8) لسنة 1972.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (8) لسنة 1972.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (8) لسنة 1972.docx
#
# [36/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1997.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1997.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (1) لسنة 1997.docx
#
# [37/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم  (23) لسنة  1993.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم  (23) لسنة  1993.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم  (23) لسنة  1993.docx
#
# [38/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 2000.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 2000.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 2000.docx
#
# [39/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1984.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1984.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1984.docx
#
# [40/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1989.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1989.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1989.docx
#
# [41/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (24) لسنة 1979.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (24) لسنة 1979.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (24) لسنة 1979.docx
#
# [42/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (17) لسنة 1989 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (17) لسنة 1989 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (17) لسنة 1989 (1).docx
#
# [43/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار – 13 – لسنة 1984.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار – 13 – لسنة 1984.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار – 13 – لسنة 1984.docx
#
# [44/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم 37 لسنة 1981 بتعيين موثق (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم 37 لسنة 1981 بتعيين موثق (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم 37 لسنة 1981 بتعيين موثق (1).docx
#
# [45/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1995.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1995.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1995.docx
#
# [46/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1989 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1989 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1989 (1).docx
#
# [47/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (3) لسنة 1993.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (3) لسنة 1993.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (3) لسنة 1993.docx
#
# [48/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 19 ) لسنة 1999.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 19 ) لسنة 1999.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 19 ) لسنة 1999.docx
#
# [49/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1999.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1999.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1999.docx
#
# [50/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1996 بتعيين مدراء.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1996 بتعيين مدراء.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1996 بتعيين مدراء.docx
#
# [51/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1998.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1998.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1998.docx
#
# [52/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (24) لسنة 1979 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (24) لسنة 1979 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (24) لسنة 1979 (1).docx
#
# [53/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 15 ) لسنة 1980.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 15 ) لسنة 1980.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 15 ) لسنة 1980.docx
#
# [54/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 2000 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 2000 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (25) لسنة 2000 (1).docx
#
# [55/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1998.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1998.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (5) لسنة 1998.docx
#
# [56/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1989.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1989.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (4) لسنة 1989.docx
#
# [57/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1999 (1).docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1999 (1).txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (15) لسنة 1999 (1).docx
#
# [58/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم ( 14) لسنة 1977.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم ( 14) لسنة 1977.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم ( 14) لسنة 1977.docx
#
# [59/59] Processing (.docx): التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1995.docx
# -> Saved text file to: ./هيئة التشريع والرأي القانوني/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1995.txt
# -> Moved original file to: ./processed_pdfs/التشريعات/سجل تعيينات المرأة/قرار رقم (2) لسنة 1995.docx
#
# ========================================
# All files processed successfully!
